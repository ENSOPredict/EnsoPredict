# %% [markdown]
# # **Seasonal Forecasting**
#
# This notebook is adapted from the AI for Earth System Science Hackathon 2020 written by Ankur Mahesh (ClimateAi)

# %% [markdown]
# ## Introduction
#
#
# El Niño/ Southern Oscillation (ENSO) is the dominant mode of variability that affects the climate on seasonal time scales.  It is measured by the Nino3.4 index, a rolling 3-month average of equatorial Pacific temperatures.  ENSO is an oscillation and is marked by two phases: El Niño, with anomalously warm equatorial Pacific temperatures, and La Niña, with anomlously cold temperatures.  Because El Niño is tied to many weather patterns around the world, such as the Indian monsoon, hurricanes in the Atlantic, and North American temperature, accurate ENSO forecasts are valuable for climate-sensitive sectors (such as agriculture, water, and energy).
#
# Existing El Niño forecasts utilize dynamical models, from the European Center for Medium-range Weather Forecasts and the National Center for Environmental Prediction. These dynamical models issue forecasts by modeling the physics of the atmosphere and ocean.  In this notebook, we will issue ENSO forecasts using machine learning, which uses statistical optimization to issue forecasts.

# %% [markdown]
# ## Software Requirements
#
# This notebook requires the following libraries: numpy, xarray, netCDF4, pandas, matplotlib, sklearn, tqdm, pytorch, scipy.  Furthermore, it is *strongly* recommended that you use this notebook on Google Colab for ease of use and for access to GPU resources.

# %%
# %matplotlib inline
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
import sklearn.ensemble
import scipy.stats
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
import sklearn.ensemble
import scipy.stats
from sklearn.model_selection import train_test_split 
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %%
#Download the required packages and the data that we will use 
#for this tutorial

# !pip install netCDF4
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Out:
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 8.7MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 50.5MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.5)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.3.0 netCDF4-1.5.4
# --2020-11-19 07:44:53--  http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc [following]
# --2020-11-19 07:44:53--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 432481041 (412M) [application/x-netcdf]
# Saving to: ‘sst.mon.mean.trefadj.anom.1880to2018.nc’
#
# sst.mon.mean.trefad 100%[===================>] 412.45M   102MB/s    in 4.2s
#
# 2020-11-19 07:44:57 (98.7 MB/s) - ‘sst.mon.mean.trefadj.anom.1880to2018.nc’ saved [432481041/432481041]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-19 07:44:57--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15449 (15K) [text/plain]
# Saving to: ‘nino34.long.anom.data.txt’
#
# nino34.long.anom.da 100%[===================>]  15.09K  --.-KB/s    in 0s
#
# 2020-11-19 07:44:57 (233 MB/s) - ‘nino34.long.anom.data.txt’ saved [15449/15449]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-19 07:44:57--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6220859592 (5.8G) [application/x-netcdf]
# Saving to: ‘MPI_tas_anomalies_regridded.nc’
#
# MPI_tas_anomalies_r 100%[===================>]   5.79G  38.4MB/s    in 2m 12s
#
# 2020-11-19 07:47:10 (45.0 MB/s) - ‘MPI_tas_anomalies_regridded.nc’ saved [6220859592/6220859592]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-19 07:47:14--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5287732392 (4.9G) [application/x-netcdf]
# Saving to: ‘CNRM_tas_anomalies_regridded.nc’
#
# CNRM_tas_anomalies_ 100%[===================>]   4.92G  23.3MB/s    in 4m 1s
#
# 2020-11-19 07:51:15 (20.9 MB/s) - ‘CNRM_tas_anomalies_regridded.nc’ saved [5287732392/5287732392]

# %% [markdown]
# ## Data
#
#
#
# *   [Cobe Sea-Surface Temperature Dataset:](https://psl.noaa.gov/data/gridded/data.cobe.html): this is a dataset of historical sea surface temperatures form 1880 to 2018
# *   [ERA 2-meter temperature anomlay](https://www.ecmwf.int/en/forecasts/datasets/reanalysis-datasets/era5)
# *   [Nino3.4 Indices](https://www.ncdc.noaa.gov/teleconnections/enso/indicators/sst/): The Nino3.4 index measures the 3-month rolling average of equatorial Pacific Ocean temperature anomalies.
# *   CNRM-CM5 pre-industrial control run climate model surface temperature
# *   Max Planck Institute CMIP5 pre-industrial control run surface temperature
#
# More information about the climate models can be found [here](https://esgf-node.llnl.gov/projects/cmip5/).
#
# The pre-industrial control runs are climate model scenarios that assume that there are no anthropogenic emissions. The reason that we use the "pre-industrial control" run of the climate models as opposed to the historical runs is that the former runs are far longer, allowing us to have more data for neural network training.

# %% [markdown]
# ### Input Variables
#
# Sea surface temperature (K)
#
# ### Output Variables
#
# Nino3.4 index (K): this metric indicates the state of ENSO.

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# ## Deep Learning
#
# Now let's try training a neural network to forecast ENSO.  Makes use of Pytorch

# %% [markdown]
# Let's get started: first, let's load the data.  **PLEASE READ THE DOCSTRING FOR THE `assemble_predictors_predictands` function!** It is essential to understand the arguments to this function as we explore different scientific/ machine learning questions later on in this hackathon.
#
# In this section, the `assemble_predictors_predictands` method has been extended to load in data from observations AND from GCMs.

# %%
#Scaffold code to load in data.  This code cell is mostly data wrangling


def load_enso_indices():
  """
  Reads in the txt data file to output a pandas Series of ENSO vals

  outputs
  -------

    pd.Series : monthly ENSO values starting from 1870-01-01
  """
  with open('nino34.long.anom.data.txt') as f:
    line = f.readline()
    enso_vals = []
    while line:
        yearly_enso_vals = map(float, line.split()[1:])
        enso_vals.extend(yearly_enso_vals)
        line = f.readline()

  enso_vals = pd.Series(enso_vals)
  enso_vals.index = pd.date_range('1870-01-01',freq='MS',
                                  periods=len(enso_vals))
  enso_vals.index = pd.to_datetime(enso_vals.index)
  return enso_vals

def assemble_predictors_predictands(start_date, end_date, lead_time, 
                                    dataset, data_format,
                                    num_input_time_steps=1,
                                    use_pca=False, n_components=32,
                                    lat_slice=None, lon_slice=None):
  """
  inputs
  ------

      start_date           str : the start date from which to extract sst
      end_date             str : the end date 
      lead_time            str : the number of months between each sst
                              value and the target Nino3.4 Index
      dataset              str : 'observations' 'CNRM' or 'MPI'
      data_format          str : 'spatial' or 'flatten'. 'spatial' preserves
                                  the lat/lon dimensions and returns an 
                                  array of shape (num_samples, num_input_time_steps,
                                  lat, lon).  'flatten' returns an array of shape
                                  (num_samples, num_input_time_steps*lat*lon)
      num_input_time_steps int : the number of time steps to use for each 
                                 predictor sample
      use_pca             bool : whether or not to apply principal components
                              analysis to the sst field
      n_components         int : the number of components to use for PCA
      lat_slice           slice: the slice of latitudes to use 
      lon_slice           slice: the slice of longitudes to use

  outputs
  -------
      Returns a tuple of the predictors (np array of sst temperature anomalies) 
      and the predictands (np array the ENSO index at the specified lead time).

  """
  file_name = {'observations' : 'sst.mon.mean.trefadj.anom.1880to2018.nc',
               'observations2': 'regridded_era_t2m_anomalies.nc',
               'CNRM'         : 'CNRM_tas_anomalies_regridded.nc',
               'MPI'          : 'MPI_tas_anomalies_regridded.nc'}[dataset]
  variable_name = {'observations' : 'sst',
                   'observations2': 't2m',
                   'CNRM'         : 'tas',
                   'MPI'          : 'tas'}[dataset]
  ds = xr.open_dataset(file_name)
  sst = ds[variable_name].sel(time=slice(start_date, end_date))
  if lat_slice is not None:
    try:
        sst=sst.sel(lat=lat_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  if lon_slice is not None:
    try:
        sst=sst.sel(lon=lon_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  
  
  num_samples = sst.shape[0]
  #sst is a (num_samples, lat, lon) array
  #the line below converts it to (num_samples, num_input_time_steps, lat, lon)
  sst = np.stack([sst.values[n-num_input_time_steps:n] for n in range(num_input_time_steps,
                                                              num_samples+1)])
  #CHALLENGE: CAN YOU IMPLEMENT THE ABOVE LINE WITHOUT A FOR LOOP?
  num_samples = sst.shape[0]

  sst[np.isnan(sst)] = 0
  if data_format=='flatten':
    #sst is a 3D array: (time_steps, lat, lon)
    #in this tutorial, we will not be using ML models that take
    #advantage of the spatial nature of global temperature
    #therefore, we reshape sst into a 2D array: (time_steps, lat*lon)
    #(At each time step, there are lat*lon predictors)
    sst = sst.reshape(num_samples, -1)
    

    #Use Principal Components Analysis, also called
    #Empirical Orthogonal Functions, to reduce the
    #dimensionality of the array
    if use_pca:
      pca = sklearn.decomposition.PCA(n_components=n_components)
      pca.fit(sst)
      X = pca.transform(sst)
    else:
      X = sst
  else: # data_format=='spatial'
    X = sst

  start_date_plus_lead = pd.to_datetime(start_date) + \
                        pd.DateOffset(months=lead_time+num_input_time_steps-1)
  end_date_plus_lead = pd.to_datetime(end_date) + \
                      pd.DateOffset(months=lead_time)
  if dataset == 'observations':
    y = load_enso_indices()[slice(start_date_plus_lead, 
                                  end_date_plus_lead)]
  else: #the data is from a GCM
    X = X.astype(np.float32)
    #The Nino3.4 Index is composed of three month rolling values
    #Therefore, when calculating the Nino3.4 Index in a GCM
    #we have to extract the two months prior to the first target start date
    target_start_date_with_2_month = start_date_plus_lead - pd.DateOffset(months=2)
    subsetted_ds = ds[variable_name].sel(time=slice(target_start_date_with_2_month,
                                                   end_date_plus_lead))
    #Calculate the Nino3.4 index
    y = subsetted_ds.sel(lat=slice(5,-5), lon=slice(360-170,360-120)).mean(dim=('lat','lon'))

    y = pd.Series(y.values).rolling(window=3).mean()[2:].values
    y = y.astype(np.float32)
  ds.close()
  return X.astype(np.float32), y.astype(np.float32)


class ENSODataset(Dataset):
    def __init__(self, predictors, predictands):
        self.predictors = predictors
        self.predictands = predictands
        assert self.predictors.shape[0] == self.predictands.shape[0], \
               "The number of predictors must equal the number of predictands!"

    def __len__(self):
        return self.predictors.shape[0]

    def __getitem__(self, idx):
        return self.predictors[idx], self.predictands[idx]

# %% [markdown]
# **IMPORTANT info about `num_input_time_steps`:** `num_input_time_steps` refers to the number of time steps for each predictor.  For example, if `num_input_time_steps` is set to 3, then the machine learning model will take 3 months as its input.  In other words, a sample predictor will be 3 months of average temperature: Jan average temperature, Feb average temperature, and March average temperature (i.e. an array of (3, lat, lon)).  The predictand will be the Niño3.4 index `lead_time` months after March.
#
# Let's define a simple convolutional neural network to start.

# %% [markdown]
# ## A Simple Convolutional Neural Network to Forecast ENSO
#
#
# Let's define a simple convolutional neural network architecture.  This architecture has 1 convolutional layer, followed by a pooling layer, followed by another convolutional layer, followed by three fully connected layers (called `nn.Linear` layers).  The output of the final fully connected layer is a 1-D array, since we are trying to forecast 1 value: the target ENSO index.

# %%
class CNN(nn.Module):
    def __init__(self, num_input_time_steps=1, print_feature_dimension=False):
        """
        inputs
        -------
            num_input_time_steps        (int) : the number of input time
                                                steps in the predictor
            print_feature_dimension    (bool) : whether or not to print
                                                out the dimension of the features
                                                extracted from the conv layers
        """
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(num_input_time_steps, 6, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.print_layer = Print()
        
        #ATTENTION EXERCISE 9: print out the dimension of the extracted features from 
        #the conv layers for setting the dimension of the linear layer!
        #Using the print_layer, we find that the dimensions are 
        #(batch_size, 16, 42, 87)
        self.fc1 = nn.Linear(16 * 42 * 87, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)
        self.print_feature_dimension = print_feature_dimension

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        if self.print_feature_dimension:
          x = self.print_layer(x)
        x = x.view(-1, 16 * 42 * 87)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class Print(nn.Module):
    """
    This class prints out the size of the features
    """
    def forward(self, x):
        print(x.size())
        return x

# %% [markdown]
# Next, let's define a method that trains our neural network.
#
# **IMPORTANT** Reading through this method will help you understand each step in the process of training a neural network!

# %%
def train_network(net, criterion, optimizer, trainloader, testloader, 
                  experiment_name, num_epochs=40, classification=False):
  """
  inputs
  ------

      net               (nn.Module)   : the neural network architecture
      criterion         (nn)          : the loss function (i.e. root mean squared error)
      optimizer         (torch.optim) : the optimizer to use update the neural network 
                                        architecture to minimize the loss function
      trainloader       (torch.utils.data.DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the train dataset
      testloader        (torch.utils.data. DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the test dataset
  outputs
  -------
      predictions (np.array), and saves the trained neural network as a .pt file
  """
  #device = "cpu"
  device = "cuda:0" if torch.cuda.is_available() else "cpu"
  net = net.to(device)
  best_loss = np.infty
  train_losses, test_losses = [], []

  for epoch in range(num_epochs):
    print(epoch)
    for mode, data_loader in [('train', trainloader), ('test', testloader)]:
      #Set the model to train mode to allow its weights to be updated
      #while training
      if mode == 'train':
        net.train()

      #Set the model to eval model to prevent its weights from being updated
      #while testing
      elif mode == 'test':
        net.eval()

      running_loss = 0.0
      for i, data in enumerate(data_loader):
          # get a mini-batch of predictors and predictands
          batch_predictors, batch_predictands = data
          batch_predictands = batch_predictands.to(device)
          batch_predictors = batch_predictors.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          #calculate the predictions of the current neural network
          predictions = net(batch_predictors).squeeze()

          #quantify the quality of the predictions using a
          #loss function (aka criterion) that is differentiable
          loss = criterion(predictions, batch_predictands.squeeze())

          if mode == 'train':
            #the 'backward pass: calculates the gradients of each weight
            #of the neural network with respect to the loss
            loss.backward()

            #the optimizer updates the weights of the neural network
            #based on the gradients calculated above and the choice
            #of optimization algorithm
            optimizer.step()
          
          #Save the model weights that have the best performance!
        

          running_loss += loss.item()
      if running_loss < best_loss and mode == 'test':
          best_loss = running_loss
          torch.save(net, '{}.pt'.format(experiment_name))
      print('{} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, \
                                            running_loss/len(data_loader)))
      if mode == 'train':
          train_losses.append(running_loss/len(data_loader))
      else:
          test_losses.append(running_loss/len(data_loader))
    
  net = torch.load('{}.pt'.format(experiment_name))
  net.eval()
  net.to(device)
  
  #the remainder of this notebook calculates the predictions of the best
  #saved model
  predictions = np.asarray([])
  for i, data in enumerate(testloader):
    batch_predictors, batch_predictands = data
    batch_predictands = batch_predictands.to(device)
    batch_predictors = batch_predictors.to(device)

    batch_predictions = net(batch_predictors).squeeze()
    #Edge case: if there is 1 item in the batch, batch_predictions becomes a float
    #not a Tensor. the if statement below converts it to a Tensor
    #so that it is compatible with np.concatenate
    if len(batch_predictions.size()) == 0:
      batch_predictions = torch.Tensor([batch_predictions])
    predictions = np.concatenate([predictions, batch_predictions.detach().cpu().numpy()])
  if classification == True:
    predictions = np.where(predictions<=0, 0, predictions) 
    predictions = np.where(predictions>0, 1, predictions)
  return predictions, train_losses, test_losses

# %% [markdown]
# ## Using GCMs input
#
# With simulated data, neural networks are able to see more data and thus learn better. The cell below shows how to use xarray

# %%
#Assemble numpy arrays corresponding to predictors and predictands
train_start_date = '1860-01-01'
train_end_date = '2200-12-31'
num_input_time_steps = 2
lead_time = 3 # 1,2,3,4,... 12
climate_model = 'MPI'  # CNRM


train_predictors, train_predictands = assemble_predictors_predictands(train_start_date,
                      train_end_date, lead_time, climate_model, 'spatial', num_input_time_steps=num_input_time_steps)
test_predictors, test_predictands = assemble_predictors_predictands('1981-01-01',
                    '2010-12-31', lead_time, 'observations', 'spatial', num_input_time_steps=num_input_time_steps)

#Convert the numpy ararys into ENSODataset, which is a subset of the 
#torch.utils.data.Dataset class.  This class is compatible with
#the torch dataloader, which allows for data loading for a CNN
train_dataset = ENSODataset(train_predictors, train_predictands)
test_dataset = ENSODataset(test_predictors, test_predictands)

#Create a torch.utils.data.DataLoader from the ENSODatasets() created earlier!
#the similarity between the name DataLoader and Dataset in the pytorch API is unfortunate...
trainloader = DataLoader(train_dataset, batch_size=64)
testloader = DataLoader(test_dataset, batch_size=64)
net = CNN(num_input_time_steps=num_input_time_steps)
optimizer = optim.Adam(net.parameters(), lr=0.000001)

experiment_name = "twolayerCNN_MPI_{}_{}_lead_time{}".format(lead_time, train_start_date, train_end_date)
predictions, train_losses, test_losses = train_network(net, nn.MSELoss(), 
                  optimizer, trainloader, testloader, experiment_name,
                  num_epochs=200)
# Out:
# /usr/local/lib/python3.6/dist-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# 0
# train Set: Epoch 01. loss: 0.594629
# test Set: Epoch 01. loss: 0.815317
# 1
# train Set: Epoch 02. loss: 0.556387
# test Set: Epoch 02. loss: 0.787086
# 2
# train Set: Epoch 03. loss: 0.510079
# test Set: Epoch 03. loss: 0.755310
# 3
# train Set: Epoch 04. loss: 0.463675
# test Set: Epoch 04. loss: 0.722964
# 4
# train Set: Epoch 05. loss: 0.422284
# test Set: Epoch 05. loss: 0.693127
# 5
# train Set: Epoch 06. loss: 0.385399
# test Set: Epoch 06. loss: 0.665089
# 6
# train Set: Epoch 07. loss: 0.352938
# test Set: Epoch 07. loss: 0.638097
# 7
# train Set: Epoch 08. loss: 0.325534
# test Set: Epoch 08. loss: 0.614345
# 8
# train Set: Epoch 09. loss: 0.302094
# test Set: Epoch 09. loss: 0.593236
# 9
# train Set: Epoch 10. loss: 0.281066
# test Set: Epoch 10. loss: 0.573492
# 10
# train Set: Epoch 11. loss: 0.261093
# test Set: Epoch 11. loss: 0.554458
# 11
# train Set: Epoch 12. loss: 0.242250
# test Set: Epoch 12. loss: 0.535577
# 12
# train Set: Epoch 13. loss: 0.225258
# test Set: Epoch 13. loss: 0.518247
# 13
# train Set: Epoch 14. loss: 0.210147
# test Set: Epoch 14. loss: 0.502766
# 14
# train Set: Epoch 15. loss: 0.195981
# test Set: Epoch 15. loss: 0.487552
# 15
# train Set: Epoch 16. loss: 0.183395
# test Set: Epoch 16. loss: 0.474460
# 16
# train Set: Epoch 17. loss: 0.172378
# test Set: Epoch 17. loss: 0.462956
# 17
# train Set: Epoch 18. loss: 0.162621
# test Set: Epoch 18. loss: 0.452627
# 18
# train Set: Epoch 19. loss: 0.153949
# test Set: Epoch 19. loss: 0.443383
# 19
# train Set: Epoch 20. loss: 0.146186
# test Set: Epoch 20. loss: 0.435125
# 20
# train Set: Epoch 21. loss: 0.139219
# test Set: Epoch 21. loss: 0.427629
# 21
# train Set: Epoch 22. loss: 0.132921
# test Set: Epoch 22. loss: 0.420924
# 22
# train Set: Epoch 23. loss: 0.127253
# test Set: Epoch 23. loss: 0.414728
# 23
# train Set: Epoch 24. loss: 0.122128
# test Set: Epoch 24. loss: 0.409179
# 24
# train Set: Epoch 25. loss: 0.117505
# test Set: Epoch 25. loss: 0.404047
# 25
# train Set: Epoch 26. loss: 0.113304
# test Set: Epoch 26. loss: 0.399550
# 26
# train Set: Epoch 27. loss: 0.109493
# test Set: Epoch 27. loss: 0.395536
# 27
# train Set: Epoch 28. loss: 0.106007
# test Set: Epoch 28. loss: 0.391769
# 28
# train Set: Epoch 29. loss: 0.102783
# test Set: Epoch 29. loss: 0.388250
# 29
# train Set: Epoch 30. loss: 0.099848
# test Set: Epoch 30. loss: 0.385028
# 30
# train Set: Epoch 31. loss: 0.097149
# test Set: Epoch 31. loss: 0.382117
# 31
# train Set: Epoch 32. loss: 0.094658
# test Set: Epoch 32. loss: 0.379432
# 32
# train Set: Epoch 33. loss: 0.092383
# test Set: Epoch 33. loss: 0.376978
# 33
# train Set: Epoch 34. loss: 0.090278
# test Set: Epoch 34. loss: 0.374781
# 34
# train Set: Epoch 35. loss: 0.088335
# test Set: Epoch 35. loss: 0.372729
# 35
# train Set: Epoch 36. loss: 0.086522
# test Set: Epoch 36. loss: 0.370856
# 36
# train Set: Epoch 37. loss: 0.084820
# test Set: Epoch 37. loss: 0.369169
# 37
# train Set: Epoch 38. loss: 0.083225
# test Set: Epoch 38. loss: 0.367590
# 38
# train Set: Epoch 39. loss: 0.081718
# test Set: Epoch 39. loss: 0.366199
# 39
# train Set: Epoch 40. loss: 0.080298
# test Set: Epoch 40. loss: 0.364878
# 40
# train Set: Epoch 41. loss: 0.078972
# test Set: Epoch 41. loss: 0.363611
# 41
# train Set: Epoch 42. loss: 0.077701
# test Set: Epoch 42. loss: 0.362471
# 42
# train Set: Epoch 43. loss: 0.076483
# test Set: Epoch 43. loss: 0.361367
# 43
# train Set: Epoch 44. loss: 0.075341
# test Set: Epoch 44. loss: 0.360356
# 44
# train Set: Epoch 45. loss: 0.074238
# test Set: Epoch 45. loss: 0.359348
# 45
# train Set: Epoch 46. loss: 0.073182
# test Set: Epoch 46. loss: 0.358442
# 46
# train Set: Epoch 47. loss: 0.072167
# test Set: Epoch 47. loss: 0.357615
# 47
# train Set: Epoch 48. loss: 0.071195
# test Set: Epoch 48. loss: 0.356873
# 48
# train Set: Epoch 49. loss: 0.070256
# test Set: Epoch 49. loss: 0.356061
# 49
# train Set: Epoch 50. loss: 0.069342
# test Set: Epoch 50. loss: 0.355416
# 50
# train Set: Epoch 51. loss: 0.068469
# test Set: Epoch 51. loss: 0.354700
# 51
# train Set: Epoch 52. loss: 0.067611
# test Set: Epoch 52. loss: 0.354115
# 52
# train Set: Epoch 53. loss: 0.066799
# test Set: Epoch 53. loss: 0.353481
# 53
# train Set: Epoch 54. loss: 0.065997
# test Set: Epoch 54. loss: 0.352884
# 54
# train Set: Epoch 55. loss: 0.065220
# test Set: Epoch 55. loss: 0.352362
# 55
# train Set: Epoch 56. loss: 0.064465
# test Set: Epoch 56. loss: 0.351808
# 56
# train Set: Epoch 57. loss: 0.063732
# test Set: Epoch 57. loss: 0.351353
# 57
# train Set: Epoch 58. loss: 0.063017
# test Set: Epoch 58. loss: 0.350777
# 58
# train Set: Epoch 59. loss: 0.062321
# test Set: Epoch 59. loss: 0.350375
# 59
# train Set: Epoch 60. loss: 0.061642
# test Set: Epoch 60. loss: 0.349900
# 60
# train Set: Epoch 61. loss: 0.060975
# test Set: Epoch 61. loss: 0.349478
# 61
# train Set: Epoch 62. loss: 0.060322
# test Set: Epoch 62. loss: 0.349069
# 62
# train Set: Epoch 63. loss: 0.059687
# test Set: Epoch 63. loss: 0.348676
# 63
# train Set: Epoch 64. loss: 0.059062
# test Set: Epoch 64. loss: 0.348284
# 64
# train Set: Epoch 65. loss: 0.058442
# test Set: Epoch 65. loss: 0.347885
# 65
# train Set: Epoch 66. loss: 0.057837
# test Set: Epoch 66. loss: 0.347564
# 66
# train Set: Epoch 67. loss: 0.057248
# test Set: Epoch 67. loss: 0.347197
# 67
# train Set: Epoch 68. loss: 0.056663
# test Set: Epoch 68. loss: 0.346854
# 68
# train Set: Epoch 69. loss: 0.056090
# test Set: Epoch 69. loss: 0.346576
# 69
# train Set: Epoch 70. loss: 0.055526
# test Set: Epoch 70. loss: 0.346274
# 70
# train Set: Epoch 71. loss: 0.054977
# test Set: Epoch 71. loss: 0.345990
# 71
# train Set: Epoch 72. loss: 0.054432
# test Set: Epoch 72. loss: 0.345747
# 72
# train Set: Epoch 73. loss: 0.053896
# test Set: Epoch 73. loss: 0.345438
# 73
# train Set: Epoch 74. loss: 0.053363
# test Set: Epoch 74. loss: 0.345203
# 74
# train Set: Epoch 75. loss: 0.052844
# test Set: Epoch 75. loss: 0.345020
# 75
# train Set: Epoch 76. loss: 0.052339
# test Set: Epoch 76. loss: 0.344746
# 76
# train Set: Epoch 77. loss: 0.051838
# test Set: Epoch 77. loss: 0.344559
# 77
# train Set: Epoch 78. loss: 0.051342
# test Set: Epoch 78. loss: 0.344378
# 78
# train Set: Epoch 79. loss: 0.050855
# test Set: Epoch 79. loss: 0.344164
# 79
# train Set: Epoch 80. loss: 0.050369
# test Set: Epoch 80. loss: 0.344031
# 80
# train Set: Epoch 81. loss: 0.049891
# test Set: Epoch 81. loss: 0.343846
# 81
# train Set: Epoch 82. loss: 0.049418
# test Set: Epoch 82. loss: 0.343750
# 82
# train Set: Epoch 83. loss: 0.048958
# test Set: Epoch 83. loss: 0.343567
# 83
# train Set: Epoch 84. loss: 0.048500
# test Set: Epoch 84. loss: 0.343501
# 84
# train Set: Epoch 85. loss: 0.048052
# test Set: Epoch 85. loss: 0.343337
# 85
# train Set: Epoch 86. loss: 0.047608
# test Set: Epoch 86. loss: 0.343275
# 86
# train Set: Epoch 87. loss: 0.047172
# test Set: Epoch 87. loss: 0.343117
# 87
# train Set: Epoch 88. loss: 0.046739
# test Set: Epoch 88. loss: 0.343038
# 88
# train Set: Epoch 89. loss: 0.046311
# test Set: Epoch 89. loss: 0.342943
# 89
# train Set: Epoch 90. loss: 0.045894
# test Set: Epoch 90. loss: 0.342891
# 90
# train Set: Epoch 91. loss: 0.045478
# test Set: Epoch 91. loss: 0.342778
# 91
# train Set: Epoch 92. loss: 0.045068
# test Set: Epoch 92. loss: 0.342713
# 92
# train Set: Epoch 93. loss: 0.044666
# test Set: Epoch 93. loss: 0.342632
# 93
# train Set: Epoch 94. loss: 0.044260
# test Set: Epoch 94. loss: 0.342552
# 94
# train Set: Epoch 95. loss: 0.043863
# test Set: Epoch 95. loss: 0.342547
# 95
# train Set: Epoch 96. loss: 0.043472
# test Set: Epoch 96. loss: 0.342516
# 96
# train Set: Epoch 97. loss: 0.043089
# test Set: Epoch 97. loss: 0.342522
# 97
# train Set: Epoch 98. loss: 0.042705
# test Set: Epoch 98. loss: 0.342460
# 98
# train Set: Epoch 99. loss: 0.042328
# test Set: Epoch 99. loss: 0.342419
# 99
# train Set: Epoch 100. loss: 0.041947
# test Set: Epoch 100. loss: 0.342433
# 100
# train Set: Epoch 101. loss: 0.041575
# test Set: Epoch 101. loss: 0.342395
# 101
# train Set: Epoch 102. loss: 0.041206
# test Set: Epoch 102. loss: 0.342425
# 102
# train Set: Epoch 103. loss: 0.040843
# test Set: Epoch 103. loss: 0.342422
# 103
# train Set: Epoch 104. loss: 0.040482
# test Set: Epoch 104. loss: 0.342398
# 104
# train Set: Epoch 105. loss: 0.040121
# test Set: Epoch 105. loss: 0.342417
# 105
# train Set: Epoch 106. loss: 0.039763
# test Set: Epoch 106. loss: 0.342398
# 106
# train Set: Epoch 107. loss: 0.039411
# test Set: Epoch 107. loss: 0.342474
# 107
# train Set: Epoch 108. loss: 0.039060
# test Set: Epoch 108. loss: 0.342414
# 108
# train Set: Epoch 109. loss: 0.038719
# test Set: Epoch 109. loss: 0.342508
# 109
# train Set: Epoch 110. loss: 0.038373
# test Set: Epoch 110. loss: 0.342490
# 110
# train Set: Epoch 111. loss: 0.038035
# test Set: Epoch 111. loss: 0.342531
# 111
# train Set: Epoch 112. loss: 0.037696
# test Set: Epoch 112. loss: 0.342529
# 112
# train Set: Epoch 113. loss: 0.037364
# test Set: Epoch 113. loss: 0.342544
# 113
# train Set: Epoch 114. loss: 0.037032
# test Set: Epoch 114. loss: 0.342591
# 114
# train Set: Epoch 115. loss: 0.036703
# test Set: Epoch 115. loss: 0.342610
# 115
# train Set: Epoch 116. loss: 0.036379
# test Set: Epoch 116. loss: 0.342583
# 116
# train Set: Epoch 117. loss: 0.036056
# test Set: Epoch 117. loss: 0.342657
# 117
# train Set: Epoch 118. loss: 0.035734
# test Set: Epoch 118. loss: 0.342705
# 118
# train Set: Epoch 119. loss: 0.035415
# test Set: Epoch 119. loss: 0.342734
# 119
# train Set: Epoch 120. loss: 0.035097
# test Set: Epoch 120. loss: 0.342771
# 120
# train Set: Epoch 121. loss: 0.034781
# test Set: Epoch 121. loss: 0.342800
# 121
# train Set: Epoch 122. loss: 0.034478
# test Set: Epoch 122. loss: 0.342826
# 122
# train Set: Epoch 123. loss: 0.034166
# test Set: Epoch 123. loss: 0.342868
# 123
# train Set: Epoch 124. loss: 0.033860
# test Set: Epoch 124. loss: 0.342888
# 124
# train Set: Epoch 125. loss: 0.033556
# test Set: Epoch 125. loss: 0.342956
# 125
# train Set: Epoch 126. loss: 0.033256
# test Set: Epoch 126. loss: 0.342994
# 126
# train Set: Epoch 127. loss: 0.032961
# test Set: Epoch 127. loss: 0.342978
# 127
# train Set: Epoch 128. loss: 0.032661
# test Set: Epoch 128. loss: 0.343087
# 128
# train Set: Epoch 129. loss: 0.032364
# test Set: Epoch 129. loss: 0.343075
# 129
# train Set: Epoch 130. loss: 0.032074
# test Set: Epoch 130. loss: 0.343215
# 130
# train Set: Epoch 131. loss: 0.031782
# test Set: Epoch 131. loss: 0.343249
# 131
# train Set: Epoch 132. loss: 0.031498
# test Set: Epoch 132. loss: 0.343263
# 132
# train Set: Epoch 133. loss: 0.031210
# test Set: Epoch 133. loss: 0.343369
# 133
# train Set: Epoch 134. loss: 0.030928
# test Set: Epoch 134. loss: 0.343395
# 134
# train Set: Epoch 135. loss: 0.030649
# test Set: Epoch 135. loss: 0.343490
# 135
# train Set: Epoch 136. loss: 0.030372
# test Set: Epoch 136. loss: 0.343497
# 136
# train Set: Epoch 137. loss: 0.030094
# test Set: Epoch 137. loss: 0.343611
# 137
# train Set: Epoch 138. loss: 0.029818
# test Set: Epoch 138. loss: 0.343652
# 138
# train Set: Epoch 139. loss: 0.029542
# test Set: Epoch 139. loss: 0.343764
# 139
# train Set: Epoch 140. loss: 0.029263
# test Set: Epoch 140. loss: 0.343784
# 140
# train Set: Epoch 141. loss: 0.028994
# test Set: Epoch 141. loss: 0.343916
# 141
# train Set: Epoch 142. loss: 0.028728
# test Set: Epoch 142. loss: 0.343983
# 142
# train Set: Epoch 143. loss: 0.028453
# test Set: Epoch 143. loss: 0.344080
# 143
# train Set: Epoch 144. loss: 0.028183
# test Set: Epoch 144. loss: 0.344132
# 144
# train Set: Epoch 145. loss: 0.027921
# test Set: Epoch 145. loss: 0.344234
# 145
# train Set: Epoch 146. loss: 0.027658
# test Set: Epoch 146. loss: 0.344288
# 146
# train Set: Epoch 147. loss: 0.027397
# test Set: Epoch 147. loss: 0.344297
# 147
# train Set: Epoch 148. loss: 0.027139
# test Set: Epoch 148. loss: 0.344306
# 148
# train Set: Epoch 149. loss: 0.026878
# test Set: Epoch 149. loss: 0.344343
# 149
# train Set: Epoch 150. loss: 0.026621
# test Set: Epoch 150. loss: 0.344441
# 150
# train Set: Epoch 151. loss: 0.026371
# test Set: Epoch 151. loss: 0.344514
# 151
# train Set: Epoch 152. loss: 0.026120
# test Set: Epoch 152. loss: 0.344556
# 152
# train Set: Epoch 153. loss: 0.025869
# test Set: Epoch 153. loss: 0.344552
# 153
# train Set: Epoch 154. loss: 0.025622
# test Set: Epoch 154. loss: 0.344575
# 154
# train Set: Epoch 155. loss: 0.025375
# test Set: Epoch 155. loss: 0.344597
# 155
# train Set: Epoch 156. loss: 0.025132
# test Set: Epoch 156. loss: 0.344587
# 156
# train Set: Epoch 157. loss: 0.024888
# test Set: Epoch 157. loss: 0.344630
# 157
# train Set: Epoch 158. loss: 0.024647
# test Set: Epoch 158. loss: 0.344633
# 158
# train Set: Epoch 159. loss: 0.024411
# test Set: Epoch 159. loss: 0.344707
# 159
# train Set: Epoch 160. loss: 0.024174
# test Set: Epoch 160. loss: 0.344711
# 160
# train Set: Epoch 161. loss: 0.023942
# test Set: Epoch 161. loss: 0.344733
# 161
# train Set: Epoch 162. loss: 0.023710
# test Set: Epoch 162. loss: 0.344729
# 162
# train Set: Epoch 163. loss: 0.023477
# test Set: Epoch 163. loss: 0.344782
# 163
# train Set: Epoch 164. loss: 0.023247
# test Set: Epoch 164. loss: 0.344758
# 164
# train Set: Epoch 165. loss: 0.023015
# test Set: Epoch 165. loss: 0.344786
# 165
# train Set: Epoch 166. loss: 0.022789
# test Set: Epoch 166. loss: 0.344732
# 166
# train Set: Epoch 167. loss: 0.022566
# test Set: Epoch 167. loss: 0.344749
# 167
# train Set: Epoch 168. loss: 0.022343
# test Set: Epoch 168. loss: 0.344804
# 168
# train Set: Epoch 169. loss: 0.022124
# test Set: Epoch 169. loss: 0.344815
# 169
# train Set: Epoch 170. loss: 0.021907
# test Set: Epoch 170. loss: 0.344864
# 170
# train Set: Epoch 171. loss: 0.021688
# test Set: Epoch 171. loss: 0.344904
# 171
# train Set: Epoch 172. loss: 0.021470
# test Set: Epoch 172. loss: 0.344945
# 172
# train Set: Epoch 173. loss: 0.021254
# test Set: Epoch 173. loss: 0.344930
# 173
# train Set: Epoch 174. loss: 0.021043
# test Set: Epoch 174. loss: 0.344909
# 174
# train Set: Epoch 175. loss: 0.020831
# test Set: Epoch 175. loss: 0.344871
# 175
# train Set: Epoch 176. loss: 0.020622
# test Set: Epoch 176. loss: 0.344842
# 176
# train Set: Epoch 177. loss: 0.020413
# test Set: Epoch 177. loss: 0.344906
# 177
# train Set: Epoch 178. loss: 0.020206
# test Set: Epoch 178. loss: 0.344944
# 178
# train Set: Epoch 179. loss: 0.020004
# test Set: Epoch 179. loss: 0.344973
# 179
# train Set: Epoch 180. loss: 0.019797
# test Set: Epoch 180. loss: 0.345020
# 180
# train Set: Epoch 181. loss: 0.019593
# test Set: Epoch 181. loss: 0.345054
# 181
# train Set: Epoch 182. loss: 0.019391
# test Set: Epoch 182. loss: 0.345037
# 182
# train Set: Epoch 183. loss: 0.019189
# test Set: Epoch 183. loss: 0.345050
# 183
# train Set: Epoch 184. loss: 0.018989
# test Set: Epoch 184. loss: 0.345066
# 184
# train Set: Epoch 185. loss: 0.018795
# test Set: Epoch 185. loss: 0.345091
# 185
# train Set: Epoch 186. loss: 0.018598
# test Set: Epoch 186. loss: 0.345168
# 186
# train Set: Epoch 187. loss: 0.018404
# test Set: Epoch 187. loss: 0.345173
# 187
# train Set: Epoch 188. loss: 0.018212
# test Set: Epoch 188. loss: 0.345238
# 188
# train Set: Epoch 189. loss: 0.018023
# test Set: Epoch 189. loss: 0.345234
# 189
# train Set: Epoch 190. loss: 0.017835
# test Set: Epoch 190. loss: 0.345231
# 190
# train Set: Epoch 191. loss: 0.017647
# test Set: Epoch 191. loss: 0.345262
# 191
# train Set: Epoch 192. loss: 0.017457
# test Set: Epoch 192. loss: 0.345315
# 192
# train Set: Epoch 193. loss: 0.017270
# test Set: Epoch 193. loss: 0.345331
# 193
# train Set: Epoch 194. loss: 0.017085
# test Set: Epoch 194. loss: 0.345313
# 194
# train Set: Epoch 195. loss: 0.016904
# test Set: Epoch 195. loss: 0.345385
# 195
# train Set: Epoch 196. loss: 0.016720
# test Set: Epoch 196. loss: 0.345400
# 196
# train Set: Epoch 197. loss: 0.016538
# test Set: Epoch 197. loss: 0.345435
# 197
# train Set: Epoch 198. loss: 0.016361
# test Set: Epoch 198. loss: 0.345466
# 198
# train Set: Epoch 199. loss: 0.016183
# test Set: Epoch 199. loss: 0.345506
# 199
# train Set: Epoch 200. loss: 0.016007
# test Set: Epoch 200. loss: 0.345499

# %%
def plot_nino_time_series(y, predictions, title):
  """
  inputs
  ------
    y           pd.Series : time series of the true Nino index
    predictions np.array  : time series of the predicted Nino index (same
                            length and time as y)
    titile                : the title of the plot

  outputs
  -------
    None.  Displays the plot
  """
  predictions = pd.Series(predictions, index=y.index)
  predictions = predictions.sort_index()
  y = y.sort_index()

  plt.plot(y, label='Ground Truth')
  plt.plot(predictions, '--', label='ML Predictions')
  plt.legend(loc='best')
  plt.title(title)
  plt.ylabel('Nino3.4 Index')
  plt.xlabel('Date')
  plt.show()
  plt.close()

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Performance of {} Neural Network During Training'.format(experiment_name))
plt.legend(loc='best')
plt.show()

# %%
corr, _ = pearsonr(test_predictands, predictions)
rmse = mean_squared_error(test_predictands, predictions) ** 0.5
plot_nino_time_series(test_predictands, predictions, '{} Predictions. Corr: {:3f}. RMSE: {:3f}.'.format(experiment_name, corr, rmse))
#print(corr)
#print(rmse)
