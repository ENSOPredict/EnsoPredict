# %% [markdown]
# # **Seasonal Forecasting**
#
# This notebook is adapted from the AI for Earth System Science Hackathon 2020 written by Ankur Mahesh (ClimateAi)

# %% [markdown]
# ## Introduction
#
#
# El Niño/ Southern Oscillation (ENSO) is the dominant mode of variability that affects the climate on seasonal time scales.  It is measured by the Nino3.4 index, a rolling 3-month average of equatorial Pacific temperatures.  ENSO is an oscillation and is marked by two phases: El Niño, with anomalously warm equatorial Pacific temperatures, and La Niña, with anomlously cold temperatures.  Because El Niño is tied to many weather patterns around the world, such as the Indian monsoon, hurricanes in the Atlantic, and North American temperature, accurate ENSO forecasts are valuable for climate-sensitive sectors (such as agriculture, water, and energy).
#
# Existing El Niño forecasts utilize dynamical models, from the European Center for Medium-range Weather Forecasts and the National Center for Environmental Prediction. These dynamical models issue forecasts by modeling the physics of the atmosphere and ocean.  In this notebook, we will issue ENSO forecasts using machine learning, which uses statistical optimization to issue forecasts.

# %% [markdown]
# ## Software Requirements
#
# This notebook requires the following libraries: numpy, xarray, netCDF4, pandas, matplotlib, sklearn, tqdm, pytorch, scipy.  Furthermore, it is *strongly* recommended that you use this notebook on Google Colab for ease of use and for access to GPU resources.

# %%
# %matplotlib inline
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
import sklearn.ensemble
import scipy.stats
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %%
#Download the required packages and the data that we will use 
#for this tutorial

# !pip install netCDF4
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Out:
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 20.3MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 50.8MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.5)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.3.0 netCDF4-1.5.4
# --2020-11-30 00:31:52--  http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc [following]
# --2020-11-30 00:31:53--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 432481041 (412M) [application/x-netcdf]
# Saving to: ‘sst.mon.mean.trefadj.anom.1880to2018.nc’
#
# sst.mon.mean.trefad 100%[===================>] 412.45M  17.2MB/s    in 45s
#
# 2020-11-30 00:32:38 (9.17 MB/s) - ‘sst.mon.mean.trefadj.anom.1880to2018.nc’ saved [432481041/432481041]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:32:38--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15449 (15K) [text/plain]
# Saving to: ‘nino34.long.anom.data.txt’
#
# nino34.long.anom.da 100%[===================>]  15.09K  --.-KB/s    in 0s
#
# 2020-11-30 00:32:39 (185 MB/s) - ‘nino34.long.anom.data.txt’ saved [15449/15449]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:32:39--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6220859592 (5.8G) [application/x-netcdf]
# Saving to: ‘MPI_tas_anomalies_regridded.nc’
#
# MPI_tas_anomalies_r 100%[===================>]   5.79G  10.2MB/s    in 9m 47s
#
# 2020-11-30 00:42:26 (10.1 MB/s) - ‘MPI_tas_anomalies_regridded.nc’ saved [6220859592/6220859592]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:42:26--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5287732392 (4.9G) [application/x-netcdf]
# Saving to: ‘CNRM_tas_anomalies_regridded.nc’
#
# CNRM_tas_anomalies_ 100%[===================>]   4.92G  13.3MB/s    in 6m 37s
#
# 2020-11-30 00:49:03 (12.7 MB/s) - ‘CNRM_tas_anomalies_regridded.nc’ saved [5287732392/5287732392]

# %% [markdown]
# ## Data
#
#
#
# *   [Cobe Sea-Surface Temperature Dataset:](https://psl.noaa.gov/data/gridded/data.cobe.html): this is a dataset of historical sea surface temperatures form 1880 to 2018
# *   [ERA 2-meter temperature anomlay](https://www.ecmwf.int/en/forecasts/datasets/reanalysis-datasets/era5)
# *   [Nino3.4 Indices](https://www.ncdc.noaa.gov/teleconnections/enso/indicators/sst/): The Nino3.4 index measures the 3-month rolling average of equatorial Pacific Ocean temperature anomalies.
# *   CNRM-CM5 pre-industrial control run climate model surface temperature
# *   Max Planck Institute CMIP5 pre-industrial control run surface temperature
#
# More information about the climate models can be found [here](https://esgf-node.llnl.gov/projects/cmip5/).
#
# The pre-industrial control runs are climate model scenarios that assume that there are no anthropogenic emissions. The reason that we use the "pre-industrial control" run of the climate models as opposed to the historical runs is that the former runs are far longer, allowing us to have more data for neural network training.

# %% [markdown]
# ### Input Variables
#
# Sea surface temperature (K)
#
# ### Output Variables
#
# Nino3.4 index (K): this metric indicates the state of ENSO.

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# ## Deep Learning
#
# Now let's try training a neural network to forecast ENSO.  Makes use of Pytorch

# %% [markdown]
# Let's get started: first, let's load the data.  **PLEASE READ THE DOCSTRING FOR THE `assemble_predictors_predictands` function!** It is essential to understand the arguments to this function as we explore different scientific/ machine learning questions later on in this hackathon.
#
# In this section, the `assemble_predictors_predictands` method has been extended to load in data from observations AND from GCMs.

# %%
#Scaffold code to load in data.  This code cell is mostly data wrangling


def load_enso_indices():
  """
  Reads in the txt data file to output a pandas Series of ENSO vals

  outputs
  -------

    pd.Series : monthly ENSO values starting from 1870-01-01
  """
  with open('nino34.long.anom.data.txt') as f:
    line = f.readline()
    enso_vals = []
    while line:
        yearly_enso_vals = map(float, line.split()[1:])
        enso_vals.extend(yearly_enso_vals)
        line = f.readline()

  enso_vals = pd.Series(enso_vals)
  enso_vals.index = pd.date_range('1870-01-01',freq='MS',
                                  periods=len(enso_vals))
  enso_vals.index = pd.to_datetime(enso_vals.index)
  return enso_vals

def assemble_predictors_predictands(start_date, end_date, lead_time, 
                                    dataset, data_format,
                                    num_input_time_steps=1,
                                    use_pca=False, n_components=32,
                                    lat_slice=None, lon_slice=None):
  """
  inputs
  ------

      start_date           str : the start date from which to extract sst
      end_date             str : the end date 
      lead_time            str : the number of months between each sst
                              value and the target Nino3.4 Index
      dataset              str : 'observations' 'CNRM' or 'MPI'
      data_format          str : 'spatial' or 'flatten'. 'spatial' preserves
                                  the lat/lon dimensions and returns an 
                                  array of shape (num_samples, num_input_time_steps,
                                  lat, lon).  'flatten' returns an array of shape
                                  (num_samples, num_input_time_steps*lat*lon)
      num_input_time_steps int : the number of time steps to use for each 
                                 predictor sample
      use_pca             bool : whether or not to apply principal components
                              analysis to the sst field
      n_components         int : the number of components to use for PCA
      lat_slice           slice: the slice of latitudes to use 
      lon_slice           slice: the slice of longitudes to use

  outputs
  -------
      Returns a tuple of the predictors (np array of sst temperature anomalies) 
      and the predictands (np array the ENSO index at the specified lead time).

  """
  file_name = {'observations' : 'sst.mon.mean.trefadj.anom.1880to2018.nc',
               'observations2': 'regridded_era_t2m_anomalies.nc',
               'CNRM'         : 'CNRM_tas_anomalies_regridded.nc',
               'MPI'          : 'MPI_tas_anomalies_regridded.nc'}[dataset]
  variable_name = {'observations' : 'sst',
                   'observations2': 't2m',
                   'CNRM'         : 'tas',
                   'MPI'          : 'tas'}[dataset]
  ds = xr.open_dataset(file_name)
  sst = ds[variable_name].sel(time=slice(start_date, end_date))
  if lat_slice is not None:
    try:
        sst=sst.sel(lat=lat_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  if lon_slice is not None:
    try:
        sst=sst.sel(lon=lon_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  
  
  num_samples = sst.shape[0]
  #sst is a (num_samples, lat, lon) array
  #the line below converts it to (num_samples, num_input_time_steps, lat, lon)
  sst = np.stack([sst.values[n-num_input_time_steps:n] for n in range(num_input_time_steps,
                                                              num_samples+1)])
  #CHALLENGE: CAN YOU IMPLEMENT THE ABOVE LINE WITHOUT A FOR LOOP?
  num_samples = sst.shape[0]

  sst[np.isnan(sst)] = 0
  if data_format=='flatten':
    #sst is a 3D array: (time_steps, lat, lon)
    #in this tutorial, we will not be using ML models that take
    #advantage of the spatial nature of global temperature
    #therefore, we reshape sst into a 2D array: (time_steps, lat*lon)
    #(At each time step, there are lat*lon predictors)
    sst = sst.reshape(num_samples, -1)
    

    #Use Principal Components Analysis, also called
    #Empirical Orthogonal Functions, to reduce the
    #dimensionality of the array
    if use_pca:
      pca = sklearn.decomposition.PCA(n_components=n_components)
      pca.fit(sst)
      X = pca.transform(sst)
    else:
      X = sst
  else: # data_format=='spatial'
    X = sst

  start_date_plus_lead = pd.to_datetime(start_date) + \
                        pd.DateOffset(months=lead_time+num_input_time_steps-1)
  end_date_plus_lead = pd.to_datetime(end_date) + \
                      pd.DateOffset(months=lead_time)
  if dataset == 'observations':
    y = load_enso_indices()[slice(start_date_plus_lead, 
                                  end_date_plus_lead)]
  else: #the data is from a GCM
    X = X.astype(np.float32)
    #The Nino3.4 Index is composed of three month rolling values
    #Therefore, when calculating the Nino3.4 Index in a GCM
    #we have to extract the two months prior to the first target start date
    target_start_date_with_2_month = start_date_plus_lead - pd.DateOffset(months=2)
    subsetted_ds = ds[variable_name].sel(time=slice(target_start_date_with_2_month,
                                                   end_date_plus_lead))
    #Calculate the Nino3.4 index
    y = subsetted_ds.sel(lat=slice(5,-5), lon=slice(360-170,360-120)).mean(dim=('lat','lon'))

    y = pd.Series(y.values).rolling(window=3).mean()[2:].values
    y = y.astype(np.float32)
  ds.close()
  return X.astype(np.float32), y.astype(np.float32)


class ENSODataset(Dataset):
    def __init__(self, predictors, predictands):
        self.predictors = predictors
        self.predictands = predictands
        assert self.predictors.shape[0] == self.predictands.shape[0], \
               "The number of predictors must equal the number of predictands!"

    def __len__(self):
        return self.predictors.shape[0]

    def __getitem__(self, idx):
        return self.predictors[idx], self.predictands[idx]

# %% [markdown]
# **IMPORTANT info about `num_input_time_steps`:** `num_input_time_steps` refers to the number of time steps for each predictor.  For example, if `num_input_time_steps` is set to 3, then the machine learning model will take 3 months as its input.  In other words, a sample predictor will be 3 months of average temperature: Jan average temperature, Feb average temperature, and March average temperature (i.e. an array of (3, lat, lon)).  The predictand will be the Niño3.4 index `lead_time` months after March.
#
# Let's define a simple convolutional neural network to start.

# %% [markdown]
# ## A Simple Convolutional Neural Network to Forecast ENSO
#
#
# Let's define a simple convolutional neural network architecture.  This architecture has 1 convolutional layer, followed by a pooling layer, followed by another convolutional layer, followed by three fully connected layers (called `nn.Linear` layers).  The output of the final fully connected layer is a 1-D array, since we are trying to forecast 1 value: the target ENSO index.

# %%
class CNN(nn.Module):
    def __init__(self, num_input_time_steps=1, print_feature_dimension=False):
        """
        inputs
        -------
            num_input_time_steps        (int) : the number of input time
                                                steps in the predictor
            print_feature_dimension    (bool) : whether or not to print
                                                out the dimension of the features
                                                extracted from the conv layers
        """
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(num_input_time_steps, 6, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.print_layer = Print()
        
        #ATTENTION EXERCISE 9: print out the dimension of the extracted features from 
        #the conv layers for setting the dimension of the linear layer!
        #Using the print_layer, we find that the dimensions are 
        #(batch_size, 16, 42, 87)
        self.fc1 = nn.Linear(16 * 42 * 87, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)
        self.print_feature_dimension = print_feature_dimension

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        if self.print_feature_dimension:
          x = self.print_layer(x)
        x = x.view(-1, 16 * 42 * 87)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class Print(nn.Module):
    """
    This class prints out the size of the features
    """
    def forward(self, x):
        print(x.size())
        return x

# %% [markdown]
# Next, let's define a method that trains our neural network.
#
# **IMPORTANT** Reading through this method will help you understand each step in the process of training a neural network!

# %%
def train_network(net, criterion, optimizer, trainloader, testloader, 
                  experiment_name, num_epochs=40, classification=False):
  """
  inputs
  ------

      net               (nn.Module)   : the neural network architecture
      criterion         (nn)          : the loss function (i.e. root mean squared error)
      optimizer         (torch.optim) : the optimizer to use update the neural network 
                                        architecture to minimize the loss function
      trainloader       (torch.utils.data.DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the train dataset
      testloader        (torch.utils.data. DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the test dataset
  outputs
  -------
      predictions (np.array), and saves the trained neural network as a .pt file
  """
  device = "cuda:0" if torch.cuda.is_available() else "cpu"
  net = net.to(device)
  best_loss = np.infty
  train_losses, test_losses = [], []

  for epoch in range(num_epochs):
    for mode, data_loader in [('train', trainloader), ('test', testloader)]:
      #Set the model to train mode to allow its weights to be updated
      #while training
      if mode == 'train':
        net.train()

      #Set the model to eval model to prevent its weights from being updated
      #while testing
      elif mode == 'test':
        net.eval()

      running_loss = 0.0
      for i, data in enumerate(data_loader):
          # get a mini-batch of predictors and predictands
          batch_predictors, batch_predictands = data
          batch_predictands = batch_predictands.to(device)
          batch_predictors = batch_predictors.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          #calculate the predictions of the current neural network
          predictions = net(batch_predictors).squeeze()

          #quantify the quality of the predictions using a
          #loss function (aka criterion) that is differentiable
          loss = criterion(predictions, batch_predictands.squeeze())

          if mode == 'train':
            #the 'backward pass: calculates the gradients of each weight
            #of the neural network with respect to the loss
            loss.backward()

            #the optimizer updates the weights of the neural network
            #based on the gradients calculated above and the choice
            #of optimization algorithm
            optimizer.step()
          
          #Save the model weights that have the best performance!
        

          running_loss += loss.item()
      if running_loss < best_loss and mode == 'test':
          best_loss = running_loss
          torch.save(net, '{}.pt'.format(experiment_name))
      print('{} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, \
                                            running_loss/len(data_loader)))
      if mode == 'train':
          train_losses.append(running_loss/len(data_loader))
      else:
          test_losses.append(running_loss/len(data_loader))
    
  net = torch.load('{}.pt'.format(experiment_name))
  net.eval()
  net.to(device)
  
  #the remainder of this notebook calculates the predictions of the best
  #saved model
  predictions = np.asarray([])
  for i, data in enumerate(testloader):
    batch_predictors, batch_predictands = data
    batch_predictands = batch_predictands.to(device)
    batch_predictors = batch_predictors.to(device)

    batch_predictions = net(batch_predictors).squeeze()
    #Edge case: if there is 1 item in the batch, batch_predictions becomes a float
    #not a Tensor. the if statement below converts it to a Tensor
    #so that it is compatible with np.concatenate
    if len(batch_predictions.size()) == 0:
      batch_predictions = torch.Tensor([batch_predictions])
    predictions = np.concatenate([predictions, batch_predictions.detach().cpu().numpy()])
  if classification == True:
    predictions = np.where(predictions<=0, 0, predictions) 
    predictions = np.where(predictions>0, 1, predictions)
  return predictions, train_losses, test_losses

# %%
def plot_nino_time_series(y, predictions, title):
  """
  inputs
  ------
    y           pd.Series : time series of the true Nino index
    predictions np.array  : time series of the predicted Nino index (same
                            length and time as y)
    titile                : the title of the plot

  outputs
  -------
    None.  Displays the plot
  """
  predictions = pd.Series(predictions, index=y.index)
  predictions = predictions.sort_index()
  y = y.sort_index()

  plt.plot(y, label='Ground Truth')
  plt.plot(predictions, '--', label='ML Predictions')
  plt.legend(loc='best')
  plt.title(title)
  plt.ylabel('Nino3.4 Index')
  plt.xlabel('Date')
  plt.show()
  plt.close()

# %% [markdown]
# ## Using GCMs input
#
# With simulated data, neural networks are able to see more data and thus learn better. The cell below shows how to use xarray

# %%
#Assemble numpy arrays corresponding to predictors and predictands
train_start_date = '1860-01-01'
train_end_date = '2200-12-31'
num_input_time_steps = 1
lead_time = 8
climate_model = 'CNRM'


train_predictors, train_predictands = assemble_predictors_predictands(train_start_date,
                      train_end_date, lead_time, climate_model, 'spatial', num_input_time_steps=num_input_time_steps)
test_predictors, test_predictands = assemble_predictors_predictands('1981-01-01',
                    '2010-12-31', lead_time, 'observations', 'spatial', num_input_time_steps=num_input_time_steps)

#Convert the numpy ararys into ENSODataset, which is a subset of the 
#torch.utils.data.Dataset class.  This class is compatible with
#the torch dataloader, which allows for data loading for a CNN
train_dataset = ENSODataset(train_predictors, train_predictands)
test_dataset = ENSODataset(test_predictors, test_predictands)

#Create a torch.utils.data.DataLoader from the ENSODatasets() created earlier!
#the similarity between the name DataLoader and Dataset in the pytorch API is unfortunate...
trainloader = DataLoader(train_dataset, batch_size=64)
testloader = DataLoader(test_dataset, batch_size=64)
net = CNN(num_input_time_steps=num_input_time_steps)
optimizer = optim.Adam(net.parameters(), lr=0.000001)

experiment_name = "twolayerCNN_MPI_{}_{}_lead_time{}".format(train_start_date, train_end_date, str(lead_time))
predictions, train_losses, test_losses = train_network(net, nn.MSELoss(), 
                  optimizer, trainloader, testloader, experiment_name,
                  num_epochs=200)
# Out:
# /usr/local/lib/python3.6/dist-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# train Set: Epoch 01. loss: 0.650366
# test Set: Epoch 01. loss: 0.820788
# train Set: Epoch 02. loss: 0.640495
# test Set: Epoch 02. loss: 0.812631
# train Set: Epoch 03. loss: 0.630892
# test Set: Epoch 03. loss: 0.802997
# train Set: Epoch 04. loss: 0.619722
# test Set: Epoch 04. loss: 0.790162
# train Set: Epoch 05. loss: 0.606476
# test Set: Epoch 05. loss: 0.776856
# train Set: Epoch 06. loss: 0.592242
# test Set: Epoch 06. loss: 0.763772
# train Set: Epoch 07. loss: 0.578580
# test Set: Epoch 07. loss: 0.750614
# train Set: Epoch 08. loss: 0.565725
# test Set: Epoch 08. loss: 0.739361
# train Set: Epoch 09. loss: 0.553672
# test Set: Epoch 09. loss: 0.727892
# train Set: Epoch 10. loss: 0.541980
# test Set: Epoch 10. loss: 0.716523
# train Set: Epoch 11. loss: 0.530637
# test Set: Epoch 11. loss: 0.705372
# train Set: Epoch 12. loss: 0.519754
# test Set: Epoch 12. loss: 0.694640
# train Set: Epoch 13. loss: 0.509412
# test Set: Epoch 13. loss: 0.685145
# train Set: Epoch 14. loss: 0.499649
# test Set: Epoch 14. loss: 0.675414
# train Set: Epoch 15. loss: 0.490432
# test Set: Epoch 15. loss: 0.666586
# train Set: Epoch 16. loss: 0.481754
# test Set: Epoch 16. loss: 0.658374
# train Set: Epoch 17. loss: 0.473554
# test Set: Epoch 17. loss: 0.650395
# train Set: Epoch 18. loss: 0.465716
# test Set: Epoch 18. loss: 0.643179
# train Set: Epoch 19. loss: 0.458377
# test Set: Epoch 19. loss: 0.636412
# train Set: Epoch 20. loss: 0.451451
# test Set: Epoch 20. loss: 0.630071
# train Set: Epoch 21. loss: 0.444965
# test Set: Epoch 21. loss: 0.624034
# train Set: Epoch 22. loss: 0.438828
# test Set: Epoch 22. loss: 0.618531
# train Set: Epoch 23. loss: 0.433042
# test Set: Epoch 23. loss: 0.613365
# train Set: Epoch 24. loss: 0.427600
# test Set: Epoch 24. loss: 0.608763
# train Set: Epoch 25. loss: 0.422419
# test Set: Epoch 25. loss: 0.604193
# train Set: Epoch 26. loss: 0.417488
# test Set: Epoch 26. loss: 0.600151
# train Set: Epoch 27. loss: 0.412800
# test Set: Epoch 27. loss: 0.596140
# train Set: Epoch 28. loss: 0.408327
# test Set: Epoch 28. loss: 0.592371
# train Set: Epoch 29. loss: 0.404030
# test Set: Epoch 29. loss: 0.588924
# train Set: Epoch 30. loss: 0.399940
# test Set: Epoch 30. loss: 0.585717
# train Set: Epoch 31. loss: 0.396030
# test Set: Epoch 31. loss: 0.582781
# train Set: Epoch 32. loss: 0.392298
# test Set: Epoch 32. loss: 0.579911
# train Set: Epoch 33. loss: 0.388736
# test Set: Epoch 33. loss: 0.577416
# train Set: Epoch 34. loss: 0.385287
# test Set: Epoch 34. loss: 0.575022
# train Set: Epoch 35. loss: 0.381969
# test Set: Epoch 35. loss: 0.572823
# train Set: Epoch 36. loss: 0.378794
# test Set: Epoch 36. loss: 0.570790
# train Set: Epoch 37. loss: 0.375734
# test Set: Epoch 37. loss: 0.569030
# train Set: Epoch 38. loss: 0.372752
# test Set: Epoch 38. loss: 0.567229
# train Set: Epoch 39. loss: 0.369842
# test Set: Epoch 39. loss: 0.565451
# train Set: Epoch 40. loss: 0.367064
# test Set: Epoch 40. loss: 0.563909
# train Set: Epoch 41. loss: 0.364372
# test Set: Epoch 41. loss: 0.562524
# train Set: Epoch 42. loss: 0.361763
# test Set: Epoch 42. loss: 0.561184
# train Set: Epoch 43. loss: 0.359253
# test Set: Epoch 43. loss: 0.560015
# train Set: Epoch 44. loss: 0.356820
# test Set: Epoch 44. loss: 0.558870
# train Set: Epoch 45. loss: 0.354459
# test Set: Epoch 45. loss: 0.557838
# train Set: Epoch 46. loss: 0.352154
# test Set: Epoch 46. loss: 0.556832
# train Set: Epoch 47. loss: 0.349921
# test Set: Epoch 47. loss: 0.555914
# train Set: Epoch 48. loss: 0.347752
# test Set: Epoch 48. loss: 0.555093
# train Set: Epoch 49. loss: 0.345643
# test Set: Epoch 49. loss: 0.554224
# train Set: Epoch 50. loss: 0.343582
# test Set: Epoch 50. loss: 0.553466
# train Set: Epoch 51. loss: 0.341588
# test Set: Epoch 51. loss: 0.552822
# train Set: Epoch 52. loss: 0.339626
# test Set: Epoch 52. loss: 0.552179
# train Set: Epoch 53. loss: 0.337720
# test Set: Epoch 53. loss: 0.551563
# train Set: Epoch 54. loss: 0.335853
# test Set: Epoch 54. loss: 0.550968
# train Set: Epoch 55. loss: 0.334004
# test Set: Epoch 55. loss: 0.550362
# train Set: Epoch 56. loss: 0.332209
# test Set: Epoch 56. loss: 0.549840
# train Set: Epoch 57. loss: 0.330431
# test Set: Epoch 57. loss: 0.549286
# train Set: Epoch 58. loss: 0.328704
# test Set: Epoch 58. loss: 0.548788
# train Set: Epoch 59. loss: 0.327002
# test Set: Epoch 59. loss: 0.548326
# train Set: Epoch 60. loss: 0.325336
# test Set: Epoch 60. loss: 0.547875
# train Set: Epoch 61. loss: 0.323693
# test Set: Epoch 61. loss: 0.547371
# train Set: Epoch 62. loss: 0.322077
# test Set: Epoch 62. loss: 0.546941
# train Set: Epoch 63. loss: 0.320464
# test Set: Epoch 63. loss: 0.546494
# train Set: Epoch 64. loss: 0.318895
# test Set: Epoch 64. loss: 0.546091
# train Set: Epoch 65. loss: 0.317350
# test Set: Epoch 65. loss: 0.545642
# train Set: Epoch 66. loss: 0.315834
# test Set: Epoch 66. loss: 0.545247
# train Set: Epoch 67. loss: 0.314329
# test Set: Epoch 67. loss: 0.544929
# train Set: Epoch 68. loss: 0.312835
# test Set: Epoch 68. loss: 0.544538
# train Set: Epoch 69. loss: 0.311373
# test Set: Epoch 69. loss: 0.544118
# train Set: Epoch 70. loss: 0.309917
# test Set: Epoch 70. loss: 0.543783
# train Set: Epoch 71. loss: 0.308478
# test Set: Epoch 71. loss: 0.543463
# train Set: Epoch 72. loss: 0.307059
# test Set: Epoch 72. loss: 0.543129
# train Set: Epoch 73. loss: 0.305649
# test Set: Epoch 73. loss: 0.542815
# train Set: Epoch 74. loss: 0.304260
# test Set: Epoch 74. loss: 0.542423
# train Set: Epoch 75. loss: 0.302883
# test Set: Epoch 75. loss: 0.542134
# train Set: Epoch 76. loss: 0.301522
# test Set: Epoch 76. loss: 0.541875
# train Set: Epoch 77. loss: 0.300178
# test Set: Epoch 77. loss: 0.541598
# train Set: Epoch 78. loss: 0.298858
# test Set: Epoch 78. loss: 0.541294
# train Set: Epoch 79. loss: 0.297546
# test Set: Epoch 79. loss: 0.541016
# train Set: Epoch 80. loss: 0.296250
# test Set: Epoch 80. loss: 0.540704
# train Set: Epoch 81. loss: 0.294964
# test Set: Epoch 81. loss: 0.540453
# train Set: Epoch 82. loss: 0.293697
# test Set: Epoch 82. loss: 0.540187
# train Set: Epoch 83. loss: 0.292429
# test Set: Epoch 83. loss: 0.539885
# train Set: Epoch 84. loss: 0.291175
# test Set: Epoch 84. loss: 0.539596
# train Set: Epoch 85. loss: 0.289945
# test Set: Epoch 85. loss: 0.539329
# train Set: Epoch 86. loss: 0.288729
# test Set: Epoch 86. loss: 0.539183
# train Set: Epoch 87. loss: 0.287498
# test Set: Epoch 87. loss: 0.538924
# train Set: Epoch 88. loss: 0.286285
# test Set: Epoch 88. loss: 0.538643
# train Set: Epoch 89. loss: 0.285067
# test Set: Epoch 89. loss: 0.538390
# train Set: Epoch 90. loss: 0.283866
# test Set: Epoch 90. loss: 0.538108
# train Set: Epoch 91. loss: 0.282687
# test Set: Epoch 91. loss: 0.537872
# train Set: Epoch 92. loss: 0.281507
# test Set: Epoch 92. loss: 0.537600
# train Set: Epoch 93. loss: 0.280329
# test Set: Epoch 93. loss: 0.537270
# train Set: Epoch 94. loss: 0.279167
# test Set: Epoch 94. loss: 0.537061
# train Set: Epoch 95. loss: 0.278028
# test Set: Epoch 95. loss: 0.536854
# train Set: Epoch 96. loss: 0.276882
# test Set: Epoch 96. loss: 0.536613
# train Set: Epoch 97. loss: 0.275743
# test Set: Epoch 97. loss: 0.536381
# train Set: Epoch 98. loss: 0.274623
# test Set: Epoch 98. loss: 0.536099
# train Set: Epoch 99. loss: 0.273504
# test Set: Epoch 99. loss: 0.535916
# train Set: Epoch 100. loss: 0.272384
# test Set: Epoch 100. loss: 0.535597
# train Set: Epoch 101. loss: 0.271264
# test Set: Epoch 101. loss: 0.535325
# train Set: Epoch 102. loss: 0.270163
# test Set: Epoch 102. loss: 0.535134
# train Set: Epoch 103. loss: 0.269057
# test Set: Epoch 103. loss: 0.534851
# train Set: Epoch 104. loss: 0.267970
# test Set: Epoch 104. loss: 0.534619
# train Set: Epoch 105. loss: 0.266875
# test Set: Epoch 105. loss: 0.534366
# train Set: Epoch 106. loss: 0.265799
# test Set: Epoch 106. loss: 0.534133
# train Set: Epoch 107. loss: 0.264730
# test Set: Epoch 107. loss: 0.533911
# train Set: Epoch 108. loss: 0.263671
# test Set: Epoch 108. loss: 0.533696
# train Set: Epoch 109. loss: 0.262619
# test Set: Epoch 109. loss: 0.533478
# train Set: Epoch 110. loss: 0.261581
# test Set: Epoch 110. loss: 0.533215
# train Set: Epoch 111. loss: 0.260548
# test Set: Epoch 111. loss: 0.533018
# train Set: Epoch 112. loss: 0.259521
# test Set: Epoch 112. loss: 0.532830
# train Set: Epoch 113. loss: 0.258506
# test Set: Epoch 113. loss: 0.532524
# train Set: Epoch 114. loss: 0.257492
# test Set: Epoch 114. loss: 0.532284
# train Set: Epoch 115. loss: 0.256486
# test Set: Epoch 115. loss: 0.532003
# train Set: Epoch 116. loss: 0.255495
# test Set: Epoch 116. loss: 0.531833
# train Set: Epoch 117. loss: 0.254495
# test Set: Epoch 117. loss: 0.531669
# train Set: Epoch 118. loss: 0.253509
# test Set: Epoch 118. loss: 0.531458
# train Set: Epoch 119. loss: 0.252526
# test Set: Epoch 119. loss: 0.531278
# train Set: Epoch 120. loss: 0.251544
# test Set: Epoch 120. loss: 0.531103
# train Set: Epoch 121. loss: 0.250581
# test Set: Epoch 121. loss: 0.530929
# train Set: Epoch 122. loss: 0.249618
# test Set: Epoch 122. loss: 0.530708
# train Set: Epoch 123. loss: 0.248658
# test Set: Epoch 123. loss: 0.530465
# train Set: Epoch 124. loss: 0.247714
# test Set: Epoch 124. loss: 0.530201
# train Set: Epoch 125. loss: 0.246782
# test Set: Epoch 125. loss: 0.529919
# train Set: Epoch 126. loss: 0.245818
# test Set: Epoch 126. loss: 0.529671
# train Set: Epoch 127. loss: 0.244883
# test Set: Epoch 127. loss: 0.529447
# train Set: Epoch 128. loss: 0.243945
# test Set: Epoch 128. loss: 0.529260
# train Set: Epoch 129. loss: 0.243018
# test Set: Epoch 129. loss: 0.529030
# train Set: Epoch 130. loss: 0.242102
# test Set: Epoch 130. loss: 0.528786
# train Set: Epoch 131. loss: 0.241181
# test Set: Epoch 131. loss: 0.528577
# train Set: Epoch 132. loss: 0.240268
# test Set: Epoch 132. loss: 0.528361
# train Set: Epoch 133. loss: 0.239367
# test Set: Epoch 133. loss: 0.528125
# train Set: Epoch 134. loss: 0.238456
# test Set: Epoch 134. loss: 0.527957
# train Set: Epoch 135. loss: 0.237566
# test Set: Epoch 135. loss: 0.527714
# train Set: Epoch 136. loss: 0.236682
# test Set: Epoch 136. loss: 0.527529
# train Set: Epoch 137. loss: 0.235785
# test Set: Epoch 137. loss: 0.527313
# train Set: Epoch 138. loss: 0.234910
# test Set: Epoch 138. loss: 0.527124
# train Set: Epoch 139. loss: 0.234033
# test Set: Epoch 139. loss: 0.526918
# train Set: Epoch 140. loss: 0.233158
# test Set: Epoch 140. loss: 0.526757
# train Set: Epoch 141. loss: 0.232298
# test Set: Epoch 141. loss: 0.526515
# train Set: Epoch 142. loss: 0.231431
# test Set: Epoch 142. loss: 0.526296
# train Set: Epoch 143. loss: 0.230565
# test Set: Epoch 143. loss: 0.526197
# train Set: Epoch 144. loss: 0.229715
# test Set: Epoch 144. loss: 0.525928
# train Set: Epoch 145. loss: 0.228863
# test Set: Epoch 145. loss: 0.525714
# train Set: Epoch 146. loss: 0.228013
# test Set: Epoch 146. loss: 0.525585
# train Set: Epoch 147. loss: 0.227157
# test Set: Epoch 147. loss: 0.525441
# train Set: Epoch 148. loss: 0.226308
# test Set: Epoch 148. loss: 0.525129
# train Set: Epoch 149. loss: 0.225456
# test Set: Epoch 149. loss: 0.525034
# train Set: Epoch 150. loss: 0.224627
# test Set: Epoch 150. loss: 0.524925
# train Set: Epoch 151. loss: 0.223786
# test Set: Epoch 151. loss: 0.524777
# train Set: Epoch 152. loss: 0.222956
# test Set: Epoch 152. loss: 0.524606
# train Set: Epoch 153. loss: 0.222135
# test Set: Epoch 153. loss: 0.524534
# train Set: Epoch 154. loss: 0.221312
# test Set: Epoch 154. loss: 0.524359
# train Set: Epoch 155. loss: 0.220500
# test Set: Epoch 155. loss: 0.524101
# train Set: Epoch 156. loss: 0.219688
# test Set: Epoch 156. loss: 0.523955
# train Set: Epoch 157. loss: 0.218879
# test Set: Epoch 157. loss: 0.523732
# train Set: Epoch 158. loss: 0.218062
# test Set: Epoch 158. loss: 0.523654
# train Set: Epoch 159. loss: 0.217258
# test Set: Epoch 159. loss: 0.523375
# train Set: Epoch 160. loss: 0.216451
# test Set: Epoch 160. loss: 0.523181
# train Set: Epoch 161. loss: 0.215659
# test Set: Epoch 161. loss: 0.522967
# train Set: Epoch 162. loss: 0.214866
# test Set: Epoch 162. loss: 0.522765
# train Set: Epoch 163. loss: 0.214071
# test Set: Epoch 163. loss: 0.522602
# train Set: Epoch 164. loss: 0.213275
# test Set: Epoch 164. loss: 0.522477
# train Set: Epoch 165. loss: 0.212492
# test Set: Epoch 165. loss: 0.522259
# train Set: Epoch 166. loss: 0.211707
# test Set: Epoch 166. loss: 0.522288
# train Set: Epoch 167. loss: 0.210925
# test Set: Epoch 167. loss: 0.521953
# train Set: Epoch 168. loss: 0.210154
# test Set: Epoch 168. loss: 0.521715
# train Set: Epoch 169. loss: 0.209377
# test Set: Epoch 169. loss: 0.521671
# train Set: Epoch 170. loss: 0.208603
# test Set: Epoch 170. loss: 0.521471
# train Set: Epoch 171. loss: 0.207835
# test Set: Epoch 171. loss: 0.521357
# train Set: Epoch 172. loss: 0.207076
# test Set: Epoch 172. loss: 0.521175
# train Set: Epoch 173. loss: 0.206319
# test Set: Epoch 173. loss: 0.521015
# train Set: Epoch 174. loss: 0.205557
# test Set: Epoch 174. loss: 0.520798
# train Set: Epoch 175. loss: 0.204797
# test Set: Epoch 175. loss: 0.520732
# train Set: Epoch 176. loss: 0.204052
# test Set: Epoch 176. loss: 0.520640
# train Set: Epoch 177. loss: 0.203309
# test Set: Epoch 177. loss: 0.520611
# train Set: Epoch 178. loss: 0.202558
# test Set: Epoch 178. loss: 0.520465
# train Set: Epoch 179. loss: 0.201829
# test Set: Epoch 179. loss: 0.520449
# train Set: Epoch 180. loss: 0.201093
# test Set: Epoch 180. loss: 0.520332
# train Set: Epoch 181. loss: 0.200357
# test Set: Epoch 181. loss: 0.520226
# train Set: Epoch 182. loss: 0.199623
# test Set: Epoch 182. loss: 0.520172
# train Set: Epoch 183. loss: 0.198893
# test Set: Epoch 183. loss: 0.519929
# train Set: Epoch 184. loss: 0.198167
# test Set: Epoch 184. loss: 0.519810
# train Set: Epoch 185. loss: 0.197442
# test Set: Epoch 185. loss: 0.519721
# train Set: Epoch 186. loss: 0.196719
# test Set: Epoch 186. loss: 0.519676
# train Set: Epoch 187. loss: 0.196004
# test Set: Epoch 187. loss: 0.519533
# train Set: Epoch 188. loss: 0.195289
# test Set: Epoch 188. loss: 0.519435
# train Set: Epoch 189. loss: 0.194569
# test Set: Epoch 189. loss: 0.519419
# train Set: Epoch 190. loss: 0.193866
# test Set: Epoch 190. loss: 0.519243
# train Set: Epoch 191. loss: 0.193149
# test Set: Epoch 191. loss: 0.519124
# train Set: Epoch 192. loss: 0.192445
# test Set: Epoch 192. loss: 0.519049
# train Set: Epoch 193. loss: 0.191737
# test Set: Epoch 193. loss: 0.518940
# train Set: Epoch 194. loss: 0.191041
# test Set: Epoch 194. loss: 0.518842
# train Set: Epoch 195. loss: 0.190338
# test Set: Epoch 195. loss: 0.518788
# train Set: Epoch 196. loss: 0.189648
# test Set: Epoch 196. loss: 0.518557
# train Set: Epoch 197. loss: 0.188949
# test Set: Epoch 197. loss: 0.518490
# train Set: Epoch 198. loss: 0.188264
# test Set: Epoch 198. loss: 0.518440
# train Set: Epoch 199. loss: 0.187574
# test Set: Epoch 199. loss: 0.518252
# train Set: Epoch 200. loss: 0.186885
# test Set: Epoch 200. loss: 0.518162

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Performance of {} Neural Network During Training'.format(experiment_name))
plt.legend(loc='best')
plt.show()

corr, _ = pearsonr(test_predictands, predictions)
rmse = mean_squared_error(test_predictands, predictions) ** 0.5
plot_nino_time_series(test_predictands, predictions, '{} Predictions. Corr: {:3f}. RMSE: {:3f}.'.format(experiment_name,
                                                                      corr, rmse))

# %%
from google.colab import files
files.download('twolayerCNN_MPI_1860-01-01_2200-12-31_lead_time{}.pt'.format(lead_time))
