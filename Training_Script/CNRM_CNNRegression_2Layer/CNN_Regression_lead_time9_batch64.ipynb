# %% [markdown]
# # **Seasonal Forecasting**
#
# This notebook is adapted from the AI for Earth System Science Hackathon 2020 written by Ankur Mahesh (ClimateAi)

# %% [markdown]
# ## Introduction
#
#
# El Niño/ Southern Oscillation (ENSO) is the dominant mode of variability that affects the climate on seasonal time scales.  It is measured by the Nino3.4 index, a rolling 3-month average of equatorial Pacific temperatures.  ENSO is an oscillation and is marked by two phases: El Niño, with anomalously warm equatorial Pacific temperatures, and La Niña, with anomlously cold temperatures.  Because El Niño is tied to many weather patterns around the world, such as the Indian monsoon, hurricanes in the Atlantic, and North American temperature, accurate ENSO forecasts are valuable for climate-sensitive sectors (such as agriculture, water, and energy).
#
# Existing El Niño forecasts utilize dynamical models, from the European Center for Medium-range Weather Forecasts and the National Center for Environmental Prediction. These dynamical models issue forecasts by modeling the physics of the atmosphere and ocean.  In this notebook, we will issue ENSO forecasts using machine learning, which uses statistical optimization to issue forecasts.

# %% [markdown]
# ## Software Requirements
#
# This notebook requires the following libraries: numpy, xarray, netCDF4, pandas, matplotlib, sklearn, tqdm, pytorch, scipy.  Furthermore, it is *strongly* recommended that you use this notebook on Google Colab for ease of use and for access to GPU resources.

# %%
# %matplotlib inline
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
import sklearn.ensemble
import scipy.stats
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %%
#Download the required packages and the data that we will use 
#for this tutorial

# !pip install netCDF4
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Out:
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 13.0MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 55.3MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.5)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.3.0 netCDF4-1.5.4
# --2020-11-30 00:27:44--  http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.26, 128.55.206.24
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.26|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc [following]
# --2020-11-30 00:27:44--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 432481041 (412M) [application/x-netcdf]
# Saving to: ‘sst.mon.mean.trefadj.anom.1880to2018.nc’
#
# sst.mon.mean.trefad 100%[===================>] 412.45M  23.5MB/s    in 18s
#
# 2020-11-30 00:28:02 (22.7 MB/s) - ‘sst.mon.mean.trefadj.anom.1880to2018.nc’ saved [432481041/432481041]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:28:03--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15449 (15K) [text/plain]
# Saving to: ‘nino34.long.anom.data.txt’
#
# nino34.long.anom.da 100%[===================>]  15.09K  --.-KB/s    in 0.08s
#
# 2020-11-30 00:28:03 (193 KB/s) - ‘nino34.long.anom.data.txt’ saved [15449/15449]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:28:03--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6220859592 (5.8G) [application/x-netcdf]
# Saving to: ‘MPI_tas_anomalies_regridded.nc’
#
# MPI_tas_anomalies_r 100%[===================>]   5.79G  37.3MB/s    in 2m 40s
#
# 2020-11-30 00:30:43 (37.1 MB/s) - ‘MPI_tas_anomalies_regridded.nc’ saved [6220859592/6220859592]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:30:44--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5287732392 (4.9G) [application/x-netcdf]
# Saving to: ‘CNRM_tas_anomalies_regridded.nc’
#
# CNRM_tas_anomalies_ 100%[===================>]   4.92G  9.41MB/s    in 7m 26s
#
# 2020-11-30 00:38:10 (11.3 MB/s) - ‘CNRM_tas_anomalies_regridded.nc’ saved [5287732392/5287732392]

# %% [markdown]
# ## Data
#
#
#
# *   [Cobe Sea-Surface Temperature Dataset:](https://psl.noaa.gov/data/gridded/data.cobe.html): this is a dataset of historical sea surface temperatures form 1880 to 2018
# *   [ERA 2-meter temperature anomlay](https://www.ecmwf.int/en/forecasts/datasets/reanalysis-datasets/era5)
# *   [Nino3.4 Indices](https://www.ncdc.noaa.gov/teleconnections/enso/indicators/sst/): The Nino3.4 index measures the 3-month rolling average of equatorial Pacific Ocean temperature anomalies.
# *   CNRM-CM5 pre-industrial control run climate model surface temperature
# *   Max Planck Institute CMIP5 pre-industrial control run surface temperature
#
# More information about the climate models can be found [here](https://esgf-node.llnl.gov/projects/cmip5/).
#
# The pre-industrial control runs are climate model scenarios that assume that there are no anthropogenic emissions. The reason that we use the "pre-industrial control" run of the climate models as opposed to the historical runs is that the former runs are far longer, allowing us to have more data for neural network training.

# %% [markdown]
# ### Input Variables
#
# Sea surface temperature (K)
#
# ### Output Variables
#
# Nino3.4 index (K): this metric indicates the state of ENSO.

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# ## Deep Learning
#
# Now let's try training a neural network to forecast ENSO.  Makes use of Pytorch

# %% [markdown]
# Let's get started: first, let's load the data.  **PLEASE READ THE DOCSTRING FOR THE `assemble_predictors_predictands` function!** It is essential to understand the arguments to this function as we explore different scientific/ machine learning questions later on in this hackathon.
#
# In this section, the `assemble_predictors_predictands` method has been extended to load in data from observations AND from GCMs.

# %%
#Scaffold code to load in data.  This code cell is mostly data wrangling


def load_enso_indices():
  """
  Reads in the txt data file to output a pandas Series of ENSO vals

  outputs
  -------

    pd.Series : monthly ENSO values starting from 1870-01-01
  """
  with open('nino34.long.anom.data.txt') as f:
    line = f.readline()
    enso_vals = []
    while line:
        yearly_enso_vals = map(float, line.split()[1:])
        enso_vals.extend(yearly_enso_vals)
        line = f.readline()

  enso_vals = pd.Series(enso_vals)
  enso_vals.index = pd.date_range('1870-01-01',freq='MS',
                                  periods=len(enso_vals))
  enso_vals.index = pd.to_datetime(enso_vals.index)
  return enso_vals

def assemble_predictors_predictands(start_date, end_date, lead_time, 
                                    dataset, data_format,
                                    num_input_time_steps=1,
                                    use_pca=False, n_components=32,
                                    lat_slice=None, lon_slice=None):
  """
  inputs
  ------

      start_date           str : the start date from which to extract sst
      end_date             str : the end date 
      lead_time            str : the number of months between each sst
                              value and the target Nino3.4 Index
      dataset              str : 'observations' 'CNRM' or 'MPI'
      data_format          str : 'spatial' or 'flatten'. 'spatial' preserves
                                  the lat/lon dimensions and returns an 
                                  array of shape (num_samples, num_input_time_steps,
                                  lat, lon).  'flatten' returns an array of shape
                                  (num_samples, num_input_time_steps*lat*lon)
      num_input_time_steps int : the number of time steps to use for each 
                                 predictor sample
      use_pca             bool : whether or not to apply principal components
                              analysis to the sst field
      n_components         int : the number of components to use for PCA
      lat_slice           slice: the slice of latitudes to use 
      lon_slice           slice: the slice of longitudes to use

  outputs
  -------
      Returns a tuple of the predictors (np array of sst temperature anomalies) 
      and the predictands (np array the ENSO index at the specified lead time).

  """
  file_name = {'observations' : 'sst.mon.mean.trefadj.anom.1880to2018.nc',
               'observations2': 'regridded_era_t2m_anomalies.nc',
               'CNRM'         : 'CNRM_tas_anomalies_regridded.nc',
               'MPI'          : 'MPI_tas_anomalies_regridded.nc'}[dataset]
  variable_name = {'observations' : 'sst',
                   'observations2': 't2m',
                   'CNRM'         : 'tas',
                   'MPI'          : 'tas'}[dataset]
  ds = xr.open_dataset(file_name)
  sst = ds[variable_name].sel(time=slice(start_date, end_date))
  if lat_slice is not None:
    try:
        sst=sst.sel(lat=lat_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  if lon_slice is not None:
    try:
        sst=sst.sel(lon=lon_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  
  
  num_samples = sst.shape[0]
  #sst is a (num_samples, lat, lon) array
  #the line below converts it to (num_samples, num_input_time_steps, lat, lon)
  sst = np.stack([sst.values[n-num_input_time_steps:n] for n in range(num_input_time_steps,
                                                              num_samples+1)])
  #CHALLENGE: CAN YOU IMPLEMENT THE ABOVE LINE WITHOUT A FOR LOOP?
  num_samples = sst.shape[0]

  sst[np.isnan(sst)] = 0
  if data_format=='flatten':
    #sst is a 3D array: (time_steps, lat, lon)
    #in this tutorial, we will not be using ML models that take
    #advantage of the spatial nature of global temperature
    #therefore, we reshape sst into a 2D array: (time_steps, lat*lon)
    #(At each time step, there are lat*lon predictors)
    sst = sst.reshape(num_samples, -1)
    

    #Use Principal Components Analysis, also called
    #Empirical Orthogonal Functions, to reduce the
    #dimensionality of the array
    if use_pca:
      pca = sklearn.decomposition.PCA(n_components=n_components)
      pca.fit(sst)
      X = pca.transform(sst)
    else:
      X = sst
  else: # data_format=='spatial'
    X = sst

  start_date_plus_lead = pd.to_datetime(start_date) + \
                        pd.DateOffset(months=lead_time+num_input_time_steps-1)
  end_date_plus_lead = pd.to_datetime(end_date) + \
                      pd.DateOffset(months=lead_time)
  if dataset == 'observations':
    y = load_enso_indices()[slice(start_date_plus_lead, 
                                  end_date_plus_lead)]
  else: #the data is from a GCM
    X = X.astype(np.float32)
    #The Nino3.4 Index is composed of three month rolling values
    #Therefore, when calculating the Nino3.4 Index in a GCM
    #we have to extract the two months prior to the first target start date
    target_start_date_with_2_month = start_date_plus_lead - pd.DateOffset(months=2)
    subsetted_ds = ds[variable_name].sel(time=slice(target_start_date_with_2_month,
                                                   end_date_plus_lead))
    #Calculate the Nino3.4 index
    y = subsetted_ds.sel(lat=slice(5,-5), lon=slice(360-170,360-120)).mean(dim=('lat','lon'))

    y = pd.Series(y.values).rolling(window=3).mean()[2:].values
    y = y.astype(np.float32)
  ds.close()
  return X.astype(np.float32), y.astype(np.float32)


class ENSODataset(Dataset):
    def __init__(self, predictors, predictands):
        self.predictors = predictors
        self.predictands = predictands
        assert self.predictors.shape[0] == self.predictands.shape[0], \
               "The number of predictors must equal the number of predictands!"

    def __len__(self):
        return self.predictors.shape[0]

    def __getitem__(self, idx):
        return self.predictors[idx], self.predictands[idx]

# %% [markdown]
# **IMPORTANT info about `num_input_time_steps`:** `num_input_time_steps` refers to the number of time steps for each predictor.  For example, if `num_input_time_steps` is set to 3, then the machine learning model will take 3 months as its input.  In other words, a sample predictor will be 3 months of average temperature: Jan average temperature, Feb average temperature, and March average temperature (i.e. an array of (3, lat, lon)).  The predictand will be the Niño3.4 index `lead_time` months after March.
#
# Let's define a simple convolutional neural network to start.

# %% [markdown]
# ## A Simple Convolutional Neural Network to Forecast ENSO
#
#
# Let's define a simple convolutional neural network architecture.  This architecture has 1 convolutional layer, followed by a pooling layer, followed by another convolutional layer, followed by three fully connected layers (called `nn.Linear` layers).  The output of the final fully connected layer is a 1-D array, since we are trying to forecast 1 value: the target ENSO index.

# %%
class CNN(nn.Module):
    def __init__(self, num_input_time_steps=1, print_feature_dimension=False):
        """
        inputs
        -------
            num_input_time_steps        (int) : the number of input time
                                                steps in the predictor
            print_feature_dimension    (bool) : whether or not to print
                                                out the dimension of the features
                                                extracted from the conv layers
        """
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(num_input_time_steps, 6, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.print_layer = Print()
        
        #ATTENTION EXERCISE 9: print out the dimension of the extracted features from 
        #the conv layers for setting the dimension of the linear layer!
        #Using the print_layer, we find that the dimensions are 
        #(batch_size, 16, 42, 87)
        self.fc1 = nn.Linear(16 * 42 * 87, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)
        self.print_feature_dimension = print_feature_dimension

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        if self.print_feature_dimension:
          x = self.print_layer(x)
        x = x.view(-1, 16 * 42 * 87)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class Print(nn.Module):
    """
    This class prints out the size of the features
    """
    def forward(self, x):
        print(x.size())
        return x

# %% [markdown]
# Next, let's define a method that trains our neural network.
#
# **IMPORTANT** Reading through this method will help you understand each step in the process of training a neural network!

# %%
def train_network(net, criterion, optimizer, trainloader, testloader, 
                  experiment_name, num_epochs=40, classification=False):
  """
  inputs
  ------

      net               (nn.Module)   : the neural network architecture
      criterion         (nn)          : the loss function (i.e. root mean squared error)
      optimizer         (torch.optim) : the optimizer to use update the neural network 
                                        architecture to minimize the loss function
      trainloader       (torch.utils.data.DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the train dataset
      testloader        (torch.utils.data. DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the test dataset
  outputs
  -------
      predictions (np.array), and saves the trained neural network as a .pt file
  """
  device = "cuda:0" if torch.cuda.is_available() else "cpu"
  net = net.to(device)
  best_loss = np.infty
  train_losses, test_losses = [], []

  for epoch in range(num_epochs):
    for mode, data_loader in [('train', trainloader), ('test', testloader)]:
      #Set the model to train mode to allow its weights to be updated
      #while training
      if mode == 'train':
        net.train()

      #Set the model to eval model to prevent its weights from being updated
      #while testing
      elif mode == 'test':
        net.eval()

      running_loss = 0.0
      for i, data in enumerate(data_loader):
          # get a mini-batch of predictors and predictands
          batch_predictors, batch_predictands = data
          batch_predictands = batch_predictands.to(device)
          batch_predictors = batch_predictors.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          #calculate the predictions of the current neural network
          predictions = net(batch_predictors).squeeze()

          #quantify the quality of the predictions using a
          #loss function (aka criterion) that is differentiable
          loss = criterion(predictions, batch_predictands.squeeze())

          if mode == 'train':
            #the 'backward pass: calculates the gradients of each weight
            #of the neural network with respect to the loss
            loss.backward()

            #the optimizer updates the weights of the neural network
            #based on the gradients calculated above and the choice
            #of optimization algorithm
            optimizer.step()
          
          #Save the model weights that have the best performance!
        

          running_loss += loss.item()
      if running_loss < best_loss and mode == 'test':
          best_loss = running_loss
          torch.save(net, '{}.pt'.format(experiment_name))
      print('{} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, \
                                            running_loss/len(data_loader)))
      if mode == 'train':
          train_losses.append(running_loss/len(data_loader))
      else:
          test_losses.append(running_loss/len(data_loader))
    
  net = torch.load('{}.pt'.format(experiment_name))
  net.eval()
  net.to(device)
  
  #the remainder of this notebook calculates the predictions of the best
  #saved model
  predictions = np.asarray([])
  for i, data in enumerate(testloader):
    batch_predictors, batch_predictands = data
    batch_predictands = batch_predictands.to(device)
    batch_predictors = batch_predictors.to(device)

    batch_predictions = net(batch_predictors).squeeze()
    #Edge case: if there is 1 item in the batch, batch_predictions becomes a float
    #not a Tensor. the if statement below converts it to a Tensor
    #so that it is compatible with np.concatenate
    if len(batch_predictions.size()) == 0:
      batch_predictions = torch.Tensor([batch_predictions])
    predictions = np.concatenate([predictions, batch_predictions.detach().cpu().numpy()])
  if classification == True:
    predictions = np.where(predictions<=0, 0, predictions) 
    predictions = np.where(predictions>0, 1, predictions)
  return predictions, train_losses, test_losses

# %%
def plot_nino_time_series(y, predictions, title):
  """
  inputs
  ------
    y           pd.Series : time series of the true Nino index
    predictions np.array  : time series of the predicted Nino index (same
                            length and time as y)
    titile                : the title of the plot

  outputs
  -------
    None.  Displays the plot
  """
  predictions = pd.Series(predictions, index=y.index)
  predictions = predictions.sort_index()
  y = y.sort_index()

  plt.plot(y, label='Ground Truth')
  plt.plot(predictions, '--', label='ML Predictions')
  plt.legend(loc='best')
  plt.title(title)
  plt.ylabel('Nino3.4 Index')
  plt.xlabel('Date')
  plt.show()
  plt.close()

# %% [markdown]
# ## Using GCMs input
#
# With simulated data, neural networks are able to see more data and thus learn better. The cell below shows how to use xarray

# %%
#Assemble numpy arrays corresponding to predictors and predictands
train_start_date = '1860-01-01'
train_end_date = '2200-12-31'
num_input_time_steps = 1
lead_time = 9
climate_model = 'CNRM'


train_predictors, train_predictands = assemble_predictors_predictands(train_start_date,
                      train_end_date, lead_time, climate_model, 'spatial', num_input_time_steps=num_input_time_steps)
test_predictors, test_predictands = assemble_predictors_predictands('1981-01-01',
                    '2010-12-31', lead_time, 'observations', 'spatial', num_input_time_steps=num_input_time_steps)

#Convert the numpy ararys into ENSODataset, which is a subset of the 
#torch.utils.data.Dataset class.  This class is compatible with
#the torch dataloader, which allows for data loading for a CNN
train_dataset = ENSODataset(train_predictors, train_predictands)
test_dataset = ENSODataset(test_predictors, test_predictands)

#Create a torch.utils.data.DataLoader from the ENSODatasets() created earlier!
#the similarity between the name DataLoader and Dataset in the pytorch API is unfortunate...
trainloader = DataLoader(train_dataset, batch_size=64)
testloader = DataLoader(test_dataset, batch_size=64)
net = CNN(num_input_time_steps=num_input_time_steps)
optimizer = optim.Adam(net.parameters(), lr=0.000001)

experiment_name = "twolayerCNN_MPI_{}_{}_lead_time{}".format(train_start_date, train_end_date, str(lead_time))
predictions, train_losses, test_losses = train_network(net, nn.MSELoss(), 
                  optimizer, trainloader, testloader, experiment_name,
                  num_epochs=200)
# Out:
# /usr/local/lib/python3.6/dist-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# train Set: Epoch 01. loss: 0.656141
# test Set: Epoch 01. loss: 0.824684
# train Set: Epoch 02. loss: 0.642296
# test Set: Epoch 02. loss: 0.818173
# train Set: Epoch 03. loss: 0.628431
# test Set: Epoch 03. loss: 0.809912
# train Set: Epoch 04. loss: 0.611551
# test Set: Epoch 04. loss: 0.798110
# train Set: Epoch 05. loss: 0.590152
# test Set: Epoch 05. loss: 0.784107
# train Set: Epoch 06. loss: 0.566386
# test Set: Epoch 06. loss: 0.771421
# train Set: Epoch 07. loss: 0.545672
# test Set: Epoch 07. loss: 0.761806
# train Set: Epoch 08. loss: 0.528042
# test Set: Epoch 08. loss: 0.753415
# train Set: Epoch 09. loss: 0.512627
# test Set: Epoch 09. loss: 0.746567
# train Set: Epoch 10. loss: 0.498886
# test Set: Epoch 10. loss: 0.740390
# train Set: Epoch 11. loss: 0.486744
# test Set: Epoch 11. loss: 0.734523
# train Set: Epoch 12. loss: 0.475867
# test Set: Epoch 12. loss: 0.728907
# train Set: Epoch 13. loss: 0.466072
# test Set: Epoch 13. loss: 0.723711
# train Set: Epoch 14. loss: 0.457023
# test Set: Epoch 14. loss: 0.718822
# train Set: Epoch 15. loss: 0.448767
# test Set: Epoch 15. loss: 0.713489
# train Set: Epoch 16. loss: 0.441007
# test Set: Epoch 16. loss: 0.708822
# train Set: Epoch 17. loss: 0.433806
# test Set: Epoch 17. loss: 0.703819
# train Set: Epoch 18. loss: 0.427041
# test Set: Epoch 18. loss: 0.698746
# train Set: Epoch 19. loss: 0.420782
# test Set: Epoch 19. loss: 0.693922
# train Set: Epoch 20. loss: 0.414856
# test Set: Epoch 20. loss: 0.689284
# train Set: Epoch 21. loss: 0.409314
# test Set: Epoch 21. loss: 0.684611
# train Set: Epoch 22. loss: 0.404106
# test Set: Epoch 22. loss: 0.680430
# train Set: Epoch 23. loss: 0.399209
# test Set: Epoch 23. loss: 0.676288
# train Set: Epoch 24. loss: 0.394571
# test Set: Epoch 24. loss: 0.672304
# train Set: Epoch 25. loss: 0.390194
# test Set: Epoch 25. loss: 0.668504
# train Set: Epoch 26. loss: 0.385973
# test Set: Epoch 26. loss: 0.664751
# train Set: Epoch 27. loss: 0.381972
# test Set: Epoch 27. loss: 0.661171
# train Set: Epoch 28. loss: 0.378178
# test Set: Epoch 28. loss: 0.657670
# train Set: Epoch 29. loss: 0.374543
# test Set: Epoch 29. loss: 0.654377
# train Set: Epoch 30. loss: 0.370991
# test Set: Epoch 30. loss: 0.651054
# train Set: Epoch 31. loss: 0.367624
# test Set: Epoch 31. loss: 0.647833
# train Set: Epoch 32. loss: 0.364382
# test Set: Epoch 32. loss: 0.644718
# train Set: Epoch 33. loss: 0.361243
# test Set: Epoch 33. loss: 0.641703
# train Set: Epoch 34. loss: 0.358160
# test Set: Epoch 34. loss: 0.638659
# train Set: Epoch 35. loss: 0.355211
# test Set: Epoch 35. loss: 0.635949
# train Set: Epoch 36. loss: 0.352301
# test Set: Epoch 36. loss: 0.633259
# train Set: Epoch 37. loss: 0.349496
# test Set: Epoch 37. loss: 0.630687
# train Set: Epoch 38. loss: 0.346776
# test Set: Epoch 38. loss: 0.628226
# train Set: Epoch 39. loss: 0.344115
# test Set: Epoch 39. loss: 0.625761
# train Set: Epoch 40. loss: 0.341547
# test Set: Epoch 40. loss: 0.623371
# train Set: Epoch 41. loss: 0.339018
# test Set: Epoch 41. loss: 0.621102
# train Set: Epoch 42. loss: 0.336535
# test Set: Epoch 42. loss: 0.618945
# train Set: Epoch 43. loss: 0.334154
# test Set: Epoch 43. loss: 0.616857
# train Set: Epoch 44. loss: 0.331790
# test Set: Epoch 44. loss: 0.614783
# train Set: Epoch 45. loss: 0.329495
# test Set: Epoch 45. loss: 0.612807
# train Set: Epoch 46. loss: 0.327241
# test Set: Epoch 46. loss: 0.610873
# train Set: Epoch 47. loss: 0.325037
# test Set: Epoch 47. loss: 0.608974
# train Set: Epoch 48. loss: 0.322852
# test Set: Epoch 48. loss: 0.607181
# train Set: Epoch 49. loss: 0.320717
# test Set: Epoch 49. loss: 0.605479
# train Set: Epoch 50. loss: 0.318602
# test Set: Epoch 50. loss: 0.603809
# train Set: Epoch 51. loss: 0.316523
# test Set: Epoch 51. loss: 0.602155
# train Set: Epoch 52. loss: 0.314484
# test Set: Epoch 52. loss: 0.600560
# train Set: Epoch 53. loss: 0.312464
# test Set: Epoch 53. loss: 0.599059
# train Set: Epoch 54. loss: 0.310458
# test Set: Epoch 54. loss: 0.597516
# train Set: Epoch 55. loss: 0.308476
# test Set: Epoch 55. loss: 0.596016
# train Set: Epoch 56. loss: 0.306506
# test Set: Epoch 56. loss: 0.594670
# train Set: Epoch 57. loss: 0.304525
# test Set: Epoch 57. loss: 0.593269
# train Set: Epoch 58. loss: 0.302572
# test Set: Epoch 58. loss: 0.591918
# train Set: Epoch 59. loss: 0.300625
# test Set: Epoch 59. loss: 0.590494
# train Set: Epoch 60. loss: 0.298703
# test Set: Epoch 60. loss: 0.589133
# train Set: Epoch 61. loss: 0.296763
# test Set: Epoch 61. loss: 0.587864
# train Set: Epoch 62. loss: 0.294769
# test Set: Epoch 62. loss: 0.586594
# train Set: Epoch 63. loss: 0.292803
# test Set: Epoch 63. loss: 0.585246
# train Set: Epoch 64. loss: 0.290898
# test Set: Epoch 64. loss: 0.583901
# train Set: Epoch 65. loss: 0.289043
# test Set: Epoch 65. loss: 0.582653
# train Set: Epoch 66. loss: 0.287180
# test Set: Epoch 66. loss: 0.581404
# train Set: Epoch 67. loss: 0.285386
# test Set: Epoch 67. loss: 0.580203
# train Set: Epoch 68. loss: 0.283600
# test Set: Epoch 68. loss: 0.579102
# train Set: Epoch 69. loss: 0.281836
# test Set: Epoch 69. loss: 0.577982
# train Set: Epoch 70. loss: 0.280117
# test Set: Epoch 70. loss: 0.576931
# train Set: Epoch 71. loss: 0.278383
# test Set: Epoch 71. loss: 0.575897
# train Set: Epoch 72. loss: 0.276688
# test Set: Epoch 72. loss: 0.574863
# train Set: Epoch 73. loss: 0.275028
# test Set: Epoch 73. loss: 0.573843
# train Set: Epoch 74. loss: 0.273380
# test Set: Epoch 74. loss: 0.572885
# train Set: Epoch 75. loss: 0.271752
# test Set: Epoch 75. loss: 0.571878
# train Set: Epoch 76. loss: 0.270166
# test Set: Epoch 76. loss: 0.570903
# train Set: Epoch 77. loss: 0.268562
# test Set: Epoch 77. loss: 0.569920
# train Set: Epoch 78. loss: 0.267016
# test Set: Epoch 78. loss: 0.569003
# train Set: Epoch 79. loss: 0.265481
# test Set: Epoch 79. loss: 0.568074
# train Set: Epoch 80. loss: 0.263951
# test Set: Epoch 80. loss: 0.567206
# train Set: Epoch 81. loss: 0.262440
# test Set: Epoch 81. loss: 0.566355
# train Set: Epoch 82. loss: 0.260930
# test Set: Epoch 82. loss: 0.565485
# train Set: Epoch 83. loss: 0.259441
# test Set: Epoch 83. loss: 0.564607
# train Set: Epoch 84. loss: 0.257951
# test Set: Epoch 84. loss: 0.563822
# train Set: Epoch 85. loss: 0.256470
# test Set: Epoch 85. loss: 0.562930
# train Set: Epoch 86. loss: 0.255014
# test Set: Epoch 86. loss: 0.562175
# train Set: Epoch 87. loss: 0.253539
# test Set: Epoch 87. loss: 0.561342
# train Set: Epoch 88. loss: 0.252094
# test Set: Epoch 88. loss: 0.560644
# train Set: Epoch 89. loss: 0.250640
# test Set: Epoch 89. loss: 0.559926
# train Set: Epoch 90. loss: 0.249224
# test Set: Epoch 90. loss: 0.559176
# train Set: Epoch 91. loss: 0.247836
# test Set: Epoch 91. loss: 0.558577
# train Set: Epoch 92. loss: 0.246426
# test Set: Epoch 92. loss: 0.557892
# train Set: Epoch 93. loss: 0.245037
# test Set: Epoch 93. loss: 0.557278
# train Set: Epoch 94. loss: 0.243659
# test Set: Epoch 94. loss: 0.556662
# train Set: Epoch 95. loss: 0.242285
# test Set: Epoch 95. loss: 0.556099
# train Set: Epoch 96. loss: 0.240927
# test Set: Epoch 96. loss: 0.555427
# train Set: Epoch 97. loss: 0.239576
# test Set: Epoch 97. loss: 0.554790
# train Set: Epoch 98. loss: 0.238248
# test Set: Epoch 98. loss: 0.554246
# train Set: Epoch 99. loss: 0.236928
# test Set: Epoch 99. loss: 0.553688
# train Set: Epoch 100. loss: 0.235604
# test Set: Epoch 100. loss: 0.553053
# train Set: Epoch 101. loss: 0.234304
# test Set: Epoch 101. loss: 0.552477
# train Set: Epoch 102. loss: 0.233017
# test Set: Epoch 102. loss: 0.551927
# train Set: Epoch 103. loss: 0.231742
# test Set: Epoch 103. loss: 0.551429
# train Set: Epoch 104. loss: 0.230455
# test Set: Epoch 104. loss: 0.550846
# train Set: Epoch 105. loss: 0.229186
# test Set: Epoch 105. loss: 0.550273
# train Set: Epoch 106. loss: 0.227926
# test Set: Epoch 106. loss: 0.549727
# train Set: Epoch 107. loss: 0.226670
# test Set: Epoch 107. loss: 0.549233
# train Set: Epoch 108. loss: 0.225401
# test Set: Epoch 108. loss: 0.548779
# train Set: Epoch 109. loss: 0.224155
# test Set: Epoch 109. loss: 0.548220
# train Set: Epoch 110. loss: 0.222918
# test Set: Epoch 110. loss: 0.547717
# train Set: Epoch 111. loss: 0.221687
# test Set: Epoch 111. loss: 0.547247
# train Set: Epoch 112. loss: 0.220443
# test Set: Epoch 112. loss: 0.546691
# train Set: Epoch 113. loss: 0.219223
# test Set: Epoch 113. loss: 0.546166
# train Set: Epoch 114. loss: 0.218028
# test Set: Epoch 114. loss: 0.545700
# train Set: Epoch 115. loss: 0.216816
# test Set: Epoch 115. loss: 0.545201
# train Set: Epoch 116. loss: 0.215617
# test Set: Epoch 116. loss: 0.544684
# train Set: Epoch 117. loss: 0.214426
# test Set: Epoch 117. loss: 0.544228
# train Set: Epoch 118. loss: 0.213242
# test Set: Epoch 118. loss: 0.543771
# train Set: Epoch 119. loss: 0.212048
# test Set: Epoch 119. loss: 0.543334
# train Set: Epoch 120. loss: 0.210881
# test Set: Epoch 120. loss: 0.542903
# train Set: Epoch 121. loss: 0.209716
# test Set: Epoch 121. loss: 0.542514
# train Set: Epoch 122. loss: 0.208538
# test Set: Epoch 122. loss: 0.542073
# train Set: Epoch 123. loss: 0.207381
# test Set: Epoch 123. loss: 0.541662
# train Set: Epoch 124. loss: 0.206231
# test Set: Epoch 124. loss: 0.541261
# train Set: Epoch 125. loss: 0.205088
# test Set: Epoch 125. loss: 0.540844
# train Set: Epoch 126. loss: 0.203945
# test Set: Epoch 126. loss: 0.540478
# train Set: Epoch 127. loss: 0.202807
# test Set: Epoch 127. loss: 0.540088
# train Set: Epoch 128. loss: 0.201681
# test Set: Epoch 128. loss: 0.539719
# train Set: Epoch 129. loss: 0.200548
# test Set: Epoch 129. loss: 0.539352
# train Set: Epoch 130. loss: 0.199439
# test Set: Epoch 130. loss: 0.539059
# train Set: Epoch 131. loss: 0.198318
# test Set: Epoch 131. loss: 0.538686
# train Set: Epoch 132. loss: 0.197237
# test Set: Epoch 132. loss: 0.538329
# train Set: Epoch 133. loss: 0.196138
# test Set: Epoch 133. loss: 0.538029
# train Set: Epoch 134. loss: 0.195044
# test Set: Epoch 134. loss: 0.537641
# train Set: Epoch 135. loss: 0.193970
# test Set: Epoch 135. loss: 0.537370
# train Set: Epoch 136. loss: 0.192878
# test Set: Epoch 136. loss: 0.536966
# train Set: Epoch 137. loss: 0.191825
# test Set: Epoch 137. loss: 0.536706
# train Set: Epoch 138. loss: 0.190755
# test Set: Epoch 138. loss: 0.536385
# train Set: Epoch 139. loss: 0.189707
# test Set: Epoch 139. loss: 0.536046
# train Set: Epoch 140. loss: 0.188618
# test Set: Epoch 140. loss: 0.535664
# train Set: Epoch 141. loss: 0.187583
# test Set: Epoch 141. loss: 0.535363
# train Set: Epoch 142. loss: 0.186525
# test Set: Epoch 142. loss: 0.535002
# train Set: Epoch 143. loss: 0.185521
# test Set: Epoch 143. loss: 0.534751
# train Set: Epoch 144. loss: 0.184473
# test Set: Epoch 144. loss: 0.534414
# train Set: Epoch 145. loss: 0.183464
# test Set: Epoch 145. loss: 0.534205
# train Set: Epoch 146. loss: 0.182433
# test Set: Epoch 146. loss: 0.533950
# train Set: Epoch 147. loss: 0.181397
# test Set: Epoch 147. loss: 0.533585
# train Set: Epoch 148. loss: 0.180374
# test Set: Epoch 148. loss: 0.533231
# train Set: Epoch 149. loss: 0.179395
# test Set: Epoch 149. loss: 0.532969
# train Set: Epoch 150. loss: 0.178399
# test Set: Epoch 150. loss: 0.532743
# train Set: Epoch 151. loss: 0.177371
# test Set: Epoch 151. loss: 0.532455
# train Set: Epoch 152. loss: 0.176390
# test Set: Epoch 152. loss: 0.532234
# train Set: Epoch 153. loss: 0.175409
# test Set: Epoch 153. loss: 0.531971
# train Set: Epoch 154. loss: 0.174422
# test Set: Epoch 154. loss: 0.531687
# train Set: Epoch 155. loss: 0.173449
# test Set: Epoch 155. loss: 0.531417
# train Set: Epoch 156. loss: 0.172495
# test Set: Epoch 156. loss: 0.531230
# train Set: Epoch 157. loss: 0.171516
# test Set: Epoch 157. loss: 0.531034
# train Set: Epoch 158. loss: 0.170535
# test Set: Epoch 158. loss: 0.530752
# train Set: Epoch 159. loss: 0.169597
# test Set: Epoch 159. loss: 0.530527
# train Set: Epoch 160. loss: 0.168626
# test Set: Epoch 160. loss: 0.530296
# train Set: Epoch 161. loss: 0.167690
# test Set: Epoch 161. loss: 0.530125
# train Set: Epoch 162. loss: 0.166726
# test Set: Epoch 162. loss: 0.529895
# train Set: Epoch 163. loss: 0.165766
# test Set: Epoch 163. loss: 0.529671
# train Set: Epoch 164. loss: 0.164836
# test Set: Epoch 164. loss: 0.529538
# train Set: Epoch 165. loss: 0.163897
# test Set: Epoch 165. loss: 0.529338
# train Set: Epoch 166. loss: 0.162967
# test Set: Epoch 166. loss: 0.529190
# train Set: Epoch 167. loss: 0.162051
# test Set: Epoch 167. loss: 0.529026
# train Set: Epoch 168. loss: 0.161105
# test Set: Epoch 168. loss: 0.528775
# train Set: Epoch 169. loss: 0.160180
# test Set: Epoch 169. loss: 0.528610
# train Set: Epoch 170. loss: 0.159265
# test Set: Epoch 170. loss: 0.528392
# train Set: Epoch 171. loss: 0.158375
# test Set: Epoch 171. loss: 0.528236
# train Set: Epoch 172. loss: 0.157451
# test Set: Epoch 172. loss: 0.528041
# train Set: Epoch 173. loss: 0.156534
# test Set: Epoch 173. loss: 0.527857
# train Set: Epoch 174. loss: 0.155629
# test Set: Epoch 174. loss: 0.527735
# train Set: Epoch 175. loss: 0.154736
# test Set: Epoch 175. loss: 0.527583
# train Set: Epoch 176. loss: 0.153811
# test Set: Epoch 176. loss: 0.527344
# train Set: Epoch 177. loss: 0.152939
# test Set: Epoch 177. loss: 0.527194
# train Set: Epoch 178. loss: 0.152061
# test Set: Epoch 178. loss: 0.527038
# train Set: Epoch 179. loss: 0.151186
# test Set: Epoch 179. loss: 0.526950
# train Set: Epoch 180. loss: 0.150314
# test Set: Epoch 180. loss: 0.526791
# train Set: Epoch 181. loss: 0.149418
# test Set: Epoch 181. loss: 0.526590
# train Set: Epoch 182. loss: 0.148546
# test Set: Epoch 182. loss: 0.526466
# train Set: Epoch 183. loss: 0.147671
# test Set: Epoch 183. loss: 0.526316
# train Set: Epoch 184. loss: 0.146814
# test Set: Epoch 184. loss: 0.526184
# train Set: Epoch 185. loss: 0.145944
# test Set: Epoch 185. loss: 0.526093
# train Set: Epoch 186. loss: 0.145112
# test Set: Epoch 186. loss: 0.525980
# train Set: Epoch 187. loss: 0.144238
# test Set: Epoch 187. loss: 0.525853
# train Set: Epoch 188. loss: 0.143361
# test Set: Epoch 188. loss: 0.525723
# train Set: Epoch 189. loss: 0.142523
# test Set: Epoch 189. loss: 0.525677
# train Set: Epoch 190. loss: 0.141693
# test Set: Epoch 190. loss: 0.525580
# train Set: Epoch 191. loss: 0.140835
# test Set: Epoch 191. loss: 0.525480
# train Set: Epoch 192. loss: 0.139974
# test Set: Epoch 192. loss: 0.525320
# train Set: Epoch 193. loss: 0.139148
# test Set: Epoch 193. loss: 0.525183
# train Set: Epoch 194. loss: 0.138322
# test Set: Epoch 194. loss: 0.525112
# train Set: Epoch 195. loss: 0.137495
# test Set: Epoch 195. loss: 0.525002
# train Set: Epoch 196. loss: 0.136652
# test Set: Epoch 196. loss: 0.524871
# train Set: Epoch 197. loss: 0.135839
# test Set: Epoch 197. loss: 0.524860
# train Set: Epoch 198. loss: 0.135018
# test Set: Epoch 198. loss: 0.524740
# train Set: Epoch 199. loss: 0.134175
# test Set: Epoch 199. loss: 0.524653
# train Set: Epoch 200. loss: 0.133367
# test Set: Epoch 200. loss: 0.524543

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Performance of {} Neural Network During Training'.format(experiment_name))
plt.legend(loc='best')
plt.show()

corr, _ = pearsonr(test_predictands, predictions)
rmse = mean_squared_error(test_predictands, predictions) ** 0.5
plot_nino_time_series(test_predictands, predictions, '{} Predictions. Corr: {:3f}. RMSE: {:3f}.'.format(experiment_name,
                                                                      corr, rmse))

# %%
from google.colab import files
files.download('twolayerCNN_MPI_1860-01-01_2200-12-31_lead_time{}.pt'.format(lead_time))
