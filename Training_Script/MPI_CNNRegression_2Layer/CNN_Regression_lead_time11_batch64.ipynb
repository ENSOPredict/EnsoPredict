# %% [markdown]
# # **Seasonal Forecasting**
#
# This notebook is adapted from the AI for Earth System Science Hackathon 2020 written by Ankur Mahesh (ClimateAi)

# %% [markdown]
# ## Introduction
#
#
# El Niño/ Southern Oscillation (ENSO) is the dominant mode of variability that affects the climate on seasonal time scales.  It is measured by the Nino3.4 index, a rolling 3-month average of equatorial Pacific temperatures.  ENSO is an oscillation and is marked by two phases: El Niño, with anomalously warm equatorial Pacific temperatures, and La Niña, with anomlously cold temperatures.  Because El Niño is tied to many weather patterns around the world, such as the Indian monsoon, hurricanes in the Atlantic, and North American temperature, accurate ENSO forecasts are valuable for climate-sensitive sectors (such as agriculture, water, and energy).
#
# Existing El Niño forecasts utilize dynamical models, from the European Center for Medium-range Weather Forecasts and the National Center for Environmental Prediction. These dynamical models issue forecasts by modeling the physics of the atmosphere and ocean.  In this notebook, we will issue ENSO forecasts using machine learning, which uses statistical optimization to issue forecasts.

# %% [markdown]
# ## Software Requirements
#
# This notebook requires the following libraries: numpy, xarray, netCDF4, pandas, matplotlib, sklearn, tqdm, pytorch, scipy.  Furthermore, it is *strongly* recommended that you use this notebook on Google Colab for ease of use and for access to GPU resources.

# %%
# %matplotlib inline
import xarray as xr
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
import sklearn.ensemble
import scipy.stats
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %%
#Download the required packages and the data that we will use 
#for this tutorial

# !pip install netCDF4
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# !wget http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# !wget http://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Out:
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/09/39/3687b2ba762a709cd97e48dfaf3ae36a78ae603ec3d1487f767ad58a7b2e/netCDF4-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 15.6MB/s
# Collecting cftime
#   Downloading https://files.pythonhosted.org/packages/66/60/bad8525d2c046eb2964911bc412a85ba240b31c7b43f0c19377233992c6c/cftime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (295kB)
#      |████████████████████████████████| 296kB 50.4MB/s
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from netCDF4) (1.18.5)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.3.0 netCDF4-1.5.4
# --2020-11-30 00:32:42--  http://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc [following]
# --2020-11-30 00:32:43--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/sst.mon.mean.trefadj.anom.1880to2018.nc
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 432481041 (412M) [application/x-netcdf]
# Saving to: ‘sst.mon.mean.trefadj.anom.1880to2018.nc’
#
# sst.mon.mean.trefad 100%[===================>] 412.45M  22.9MB/s    in 18s
#
# 2020-11-30 00:33:01 (22.7 MB/s) - ‘sst.mon.mean.trefadj.anom.1880to2018.nc’ saved [432481041/432481041]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:33:01--  https://portal.nersc.gov/project/dasrepo/AGU_ML_Tutorial/nino34.long.anom.data.txt
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15449 (15K) [text/plain]
# Saving to: ‘nino34.long.anom.data.txt’
#
# nino34.long.anom.da 100%[===================>]  15.09K  --.-KB/s    in 0.08s
#
# 2020-11-30 00:33:02 (191 KB/s) - ‘nino34.long.anom.data.txt’ saved [15449/15449]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:33:02--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/MPI_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6220859592 (5.8G) [application/x-netcdf]
# Saving to: ‘MPI_tas_anomalies_regridded.nc’
#
# MPI_tas_anomalies_r 100%[===================>]   5.79G  25.1MB/s    in 9m 58s
#
# 2020-11-30 00:43:00 (9.92 MB/s) - ‘MPI_tas_anomalies_regridded.nc’ saved [6220859592/6220859592]
#
# URL transformed to HTTPS due to an HSTS policy
# --2020-11-30 00:43:00--  https://portal.nersc.gov/project/dasrepo/AMS_ML_Tutorial/CNRM_tas_anomalies_regridded.nc
# Resolving portal.nersc.gov (portal.nersc.gov)... 128.55.206.24, 128.55.206.26
# Connecting to portal.nersc.gov (portal.nersc.gov)|128.55.206.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5287732392 (4.9G) [application/x-netcdf]
# Saving to: ‘CNRM_tas_anomalies_regridded.nc’
#
# CNRM_tas_anomalies_ 100%[===================>]   4.92G  24.9MB/s    in 3m 29s
#
# 2020-11-30 00:46:29 (24.2 MB/s) - ‘CNRM_tas_anomalies_regridded.nc’ saved [5287732392/5287732392]

# %% [markdown]
# ## Data
#
#
#
# *   [Cobe Sea-Surface Temperature Dataset:](https://psl.noaa.gov/data/gridded/data.cobe.html): this is a dataset of historical sea surface temperatures form 1880 to 2018
# *   [ERA 2-meter temperature anomlay](https://www.ecmwf.int/en/forecasts/datasets/reanalysis-datasets/era5)
# *   [Nino3.4 Indices](https://www.ncdc.noaa.gov/teleconnections/enso/indicators/sst/): The Nino3.4 index measures the 3-month rolling average of equatorial Pacific Ocean temperature anomalies.
# *   CNRM-CM5 pre-industrial control run climate model surface temperature
# *   Max Planck Institute CMIP5 pre-industrial control run surface temperature
#
# More information about the climate models can be found [here](https://esgf-node.llnl.gov/projects/cmip5/).
#
# The pre-industrial control runs are climate model scenarios that assume that there are no anthropogenic emissions. The reason that we use the "pre-industrial control" run of the climate models as opposed to the historical runs is that the former runs are far longer, allowing us to have more data for neural network training.

# %% [markdown]
# ### Input Variables
#
# Sea surface temperature (K)
#
# ### Output Variables
#
# Nino3.4 index (K): this metric indicates the state of ENSO.

# %% [markdown]
# ### Data wrangling

# %% [markdown]
# ## Deep Learning
#
# Now let's try training a neural network to forecast ENSO.  Makes use of Pytorch

# %% [markdown]
# Let's get started: first, let's load the data.  **PLEASE READ THE DOCSTRING FOR THE `assemble_predictors_predictands` function!** It is essential to understand the arguments to this function as we explore different scientific/ machine learning questions later on in this hackathon.
#
# In this section, the `assemble_predictors_predictands` method has been extended to load in data from observations AND from GCMs.

# %%
#Scaffold code to load in data.  This code cell is mostly data wrangling


def load_enso_indices():
  """
  Reads in the txt data file to output a pandas Series of ENSO vals

  outputs
  -------

    pd.Series : monthly ENSO values starting from 1870-01-01
  """
  with open('nino34.long.anom.data.txt') as f:
    line = f.readline()
    enso_vals = []
    while line:
        yearly_enso_vals = map(float, line.split()[1:])
        enso_vals.extend(yearly_enso_vals)
        line = f.readline()

  enso_vals = pd.Series(enso_vals)
  enso_vals.index = pd.date_range('1870-01-01',freq='MS',
                                  periods=len(enso_vals))
  enso_vals.index = pd.to_datetime(enso_vals.index)
  return enso_vals

def assemble_predictors_predictands(start_date, end_date, lead_time, 
                                    dataset, data_format,
                                    num_input_time_steps=1,
                                    use_pca=False, n_components=32,
                                    lat_slice=None, lon_slice=None):
  """
  inputs
  ------

      start_date           str : the start date from which to extract sst
      end_date             str : the end date 
      lead_time            str : the number of months between each sst
                              value and the target Nino3.4 Index
      dataset              str : 'observations' 'CNRM' or 'MPI'
      data_format          str : 'spatial' or 'flatten'. 'spatial' preserves
                                  the lat/lon dimensions and returns an 
                                  array of shape (num_samples, num_input_time_steps,
                                  lat, lon).  'flatten' returns an array of shape
                                  (num_samples, num_input_time_steps*lat*lon)
      num_input_time_steps int : the number of time steps to use for each 
                                 predictor sample
      use_pca             bool : whether or not to apply principal components
                              analysis to the sst field
      n_components         int : the number of components to use for PCA
      lat_slice           slice: the slice of latitudes to use 
      lon_slice           slice: the slice of longitudes to use

  outputs
  -------
      Returns a tuple of the predictors (np array of sst temperature anomalies) 
      and the predictands (np array the ENSO index at the specified lead time).

  """
  file_name = {'observations' : 'sst.mon.mean.trefadj.anom.1880to2018.nc',
               'observations2': 'regridded_era_t2m_anomalies.nc',
               'CNRM'         : 'CNRM_tas_anomalies_regridded.nc',
               'MPI'          : 'MPI_tas_anomalies_regridded.nc'}[dataset]
  variable_name = {'observations' : 'sst',
                   'observations2': 't2m',
                   'CNRM'         : 'tas',
                   'MPI'          : 'tas'}[dataset]
  ds = xr.open_dataset(file_name)
  sst = ds[variable_name].sel(time=slice(start_date, end_date))
  if lat_slice is not None:
    try:
        sst=sst.sel(lat=lat_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  if lon_slice is not None:
    try:
        sst=sst.sel(lon=lon_slice)
    except:
        raise NotImplementedError("Implement slicing!")
  
  
  num_samples = sst.shape[0]
  #sst is a (num_samples, lat, lon) array
  #the line below converts it to (num_samples, num_input_time_steps, lat, lon)
  sst = np.stack([sst.values[n-num_input_time_steps:n] for n in range(num_input_time_steps,
                                                              num_samples+1)])
  #CHALLENGE: CAN YOU IMPLEMENT THE ABOVE LINE WITHOUT A FOR LOOP?
  num_samples = sst.shape[0]

  sst[np.isnan(sst)] = 0
  if data_format=='flatten':
    #sst is a 3D array: (time_steps, lat, lon)
    #in this tutorial, we will not be using ML models that take
    #advantage of the spatial nature of global temperature
    #therefore, we reshape sst into a 2D array: (time_steps, lat*lon)
    #(At each time step, there are lat*lon predictors)
    sst = sst.reshape(num_samples, -1)
    

    #Use Principal Components Analysis, also called
    #Empirical Orthogonal Functions, to reduce the
    #dimensionality of the array
    if use_pca:
      pca = sklearn.decomposition.PCA(n_components=n_components)
      pca.fit(sst)
      X = pca.transform(sst)
    else:
      X = sst
  else: # data_format=='spatial'
    X = sst

  start_date_plus_lead = pd.to_datetime(start_date) + \
                        pd.DateOffset(months=lead_time+num_input_time_steps-1)
  end_date_plus_lead = pd.to_datetime(end_date) + \
                      pd.DateOffset(months=lead_time)
  if dataset == 'observations':
    y = load_enso_indices()[slice(start_date_plus_lead, 
                                  end_date_plus_lead)]
  else: #the data is from a GCM
    X = X.astype(np.float32)
    #The Nino3.4 Index is composed of three month rolling values
    #Therefore, when calculating the Nino3.4 Index in a GCM
    #we have to extract the two months prior to the first target start date
    target_start_date_with_2_month = start_date_plus_lead - pd.DateOffset(months=2)
    subsetted_ds = ds[variable_name].sel(time=slice(target_start_date_with_2_month,
                                                   end_date_plus_lead))
    #Calculate the Nino3.4 index
    y = subsetted_ds.sel(lat=slice(5,-5), lon=slice(360-170,360-120)).mean(dim=('lat','lon'))

    y = pd.Series(y.values).rolling(window=3).mean()[2:].values
    y = y.astype(np.float32)
  ds.close()
  return X.astype(np.float32), y.astype(np.float32)


class ENSODataset(Dataset):
    def __init__(self, predictors, predictands):
        self.predictors = predictors
        self.predictands = predictands
        assert self.predictors.shape[0] == self.predictands.shape[0], \
               "The number of predictors must equal the number of predictands!"

    def __len__(self):
        return self.predictors.shape[0]

    def __getitem__(self, idx):
        return self.predictors[idx], self.predictands[idx]

# %% [markdown]
# **IMPORTANT info about `num_input_time_steps`:** `num_input_time_steps` refers to the number of time steps for each predictor.  For example, if `num_input_time_steps` is set to 3, then the machine learning model will take 3 months as its input.  In other words, a sample predictor will be 3 months of average temperature: Jan average temperature, Feb average temperature, and March average temperature (i.e. an array of (3, lat, lon)).  The predictand will be the Niño3.4 index `lead_time` months after March.
#
# Let's define a simple convolutional neural network to start.

# %% [markdown]
# ## A Simple Convolutional Neural Network to Forecast ENSO
#
#
# Let's define a simple convolutional neural network architecture.  This architecture has 1 convolutional layer, followed by a pooling layer, followed by another convolutional layer, followed by three fully connected layers (called `nn.Linear` layers).  The output of the final fully connected layer is a 1-D array, since we are trying to forecast 1 value: the target ENSO index.

# %%
class CNN(nn.Module):
    def __init__(self, num_input_time_steps=1, print_feature_dimension=False):
        """
        inputs
        -------
            num_input_time_steps        (int) : the number of input time
                                                steps in the predictor
            print_feature_dimension    (bool) : whether or not to print
                                                out the dimension of the features
                                                extracted from the conv layers
        """
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(num_input_time_steps, 6, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.print_layer = Print()
        
        #ATTENTION EXERCISE 9: print out the dimension of the extracted features from 
        #the conv layers for setting the dimension of the linear layer!
        #Using the print_layer, we find that the dimensions are 
        #(batch_size, 16, 42, 87)
        self.fc1 = nn.Linear(16 * 42 * 87, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)
        self.print_feature_dimension = print_feature_dimension

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        if self.print_feature_dimension:
          x = self.print_layer(x)
        x = x.view(-1, 16 * 42 * 87)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class Print(nn.Module):
    """
    This class prints out the size of the features
    """
    def forward(self, x):
        print(x.size())
        return x

# %% [markdown]
# Next, let's define a method that trains our neural network.
#
# **IMPORTANT** Reading through this method will help you understand each step in the process of training a neural network!

# %%
def train_network(net, criterion, optimizer, trainloader, testloader, 
                  experiment_name, num_epochs=40, classification=False):
  """
  inputs
  ------

      net               (nn.Module)   : the neural network architecture
      criterion         (nn)          : the loss function (i.e. root mean squared error)
      optimizer         (torch.optim) : the optimizer to use update the neural network 
                                        architecture to minimize the loss function
      trainloader       (torch.utils.data.DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the train dataset
      testloader        (torch.utils.data. DataLoader): dataloader that loads the
                                        predictors and predictands
                                        for the test dataset
  outputs
  -------
      predictions (np.array), and saves the trained neural network as a .pt file
  """
  device = "cuda:0" if torch.cuda.is_available() else "cpu"
  net = net.to(device)
  best_loss = np.infty
  train_losses, test_losses = [], []

  for epoch in range(num_epochs):
    for mode, data_loader in [('train', trainloader), ('test', testloader)]:
      #Set the model to train mode to allow its weights to be updated
      #while training
      if mode == 'train':
        net.train()

      #Set the model to eval model to prevent its weights from being updated
      #while testing
      elif mode == 'test':
        net.eval()

      running_loss = 0.0
      for i, data in enumerate(data_loader):
          # get a mini-batch of predictors and predictands
          batch_predictors, batch_predictands = data
          batch_predictands = batch_predictands.to(device)
          batch_predictors = batch_predictors.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          #calculate the predictions of the current neural network
          predictions = net(batch_predictors).squeeze()

          #quantify the quality of the predictions using a
          #loss function (aka criterion) that is differentiable
          loss = criterion(predictions, batch_predictands.squeeze())

          if mode == 'train':
            #the 'backward pass: calculates the gradients of each weight
            #of the neural network with respect to the loss
            loss.backward()

            #the optimizer updates the weights of the neural network
            #based on the gradients calculated above and the choice
            #of optimization algorithm
            optimizer.step()
          
          #Save the model weights that have the best performance!
        

          running_loss += loss.item()
      if running_loss < best_loss and mode == 'test':
          best_loss = running_loss
          torch.save(net, '{}.pt'.format(experiment_name))
      print('{} Set: Epoch {:02d}. loss: {:3f}'.format(mode, epoch+1, \
                                            running_loss/len(data_loader)))
      if mode == 'train':
          train_losses.append(running_loss/len(data_loader))
      else:
          test_losses.append(running_loss/len(data_loader))
    
  net = torch.load('{}.pt'.format(experiment_name))
  net.eval()
  net.to(device)
  
  #the remainder of this notebook calculates the predictions of the best
  #saved model
  predictions = np.asarray([])
  for i, data in enumerate(testloader):
    batch_predictors, batch_predictands = data
    batch_predictands = batch_predictands.to(device)
    batch_predictors = batch_predictors.to(device)

    batch_predictions = net(batch_predictors).squeeze()
    #Edge case: if there is 1 item in the batch, batch_predictions becomes a float
    #not a Tensor. the if statement below converts it to a Tensor
    #so that it is compatible with np.concatenate
    if len(batch_predictions.size()) == 0:
      batch_predictions = torch.Tensor([batch_predictions])
    predictions = np.concatenate([predictions, batch_predictions.detach().cpu().numpy()])
  if classification == True:
    predictions = np.where(predictions<=0, 0, predictions) 
    predictions = np.where(predictions>0, 1, predictions)
  return predictions, train_losses, test_losses

# %%
def plot_nino_time_series(y, predictions, title):
  """
  inputs
  ------
    y           pd.Series : time series of the true Nino index
    predictions np.array  : time series of the predicted Nino index (same
                            length and time as y)
    titile                : the title of the plot

  outputs
  -------
    None.  Displays the plot
  """
  predictions = pd.Series(predictions, index=y.index)
  predictions = predictions.sort_index()
  y = y.sort_index()

  plt.plot(y, label='Ground Truth')
  plt.plot(predictions, '--', label='ML Predictions')
  plt.legend(loc='best')
  plt.title(title)
  plt.ylabel('Nino3.4 Index')
  plt.xlabel('Date')
  plt.show()
  plt.close()

# %% [markdown]
# ## Using GCMs input
#
# With simulated data, neural networks are able to see more data and thus learn better. The cell below shows how to use xarray

# %%
#Assemble numpy arrays corresponding to predictors and predictands
train_start_date = '1860-01-01'
train_end_date = '2200-12-31'
num_input_time_steps = 1
lead_time = 11
climate_model = 'MPI'


train_predictors, train_predictands = assemble_predictors_predictands(train_start_date,
                      train_end_date, lead_time, climate_model, 'spatial', num_input_time_steps=num_input_time_steps)
test_predictors, test_predictands = assemble_predictors_predictands('1981-01-01',
                    '2010-12-31', lead_time, 'observations', 'spatial', num_input_time_steps=num_input_time_steps)

#Convert the numpy ararys into ENSODataset, which is a subset of the 
#torch.utils.data.Dataset class.  This class is compatible with
#the torch dataloader, which allows for data loading for a CNN
train_dataset = ENSODataset(train_predictors, train_predictands)
test_dataset = ENSODataset(test_predictors, test_predictands)

#Create a torch.utils.data.DataLoader from the ENSODatasets() created earlier!
#the similarity between the name DataLoader and Dataset in the pytorch API is unfortunate...
trainloader = DataLoader(train_dataset, batch_size=64)
testloader = DataLoader(test_dataset, batch_size=64)
net = CNN(num_input_time_steps=num_input_time_steps)
optimizer = optim.Adam(net.parameters(), lr=0.000001)

experiment_name = "twolayerCNN_MPI_{}_{}_lead_time{}".format(train_start_date, train_end_date, str(lead_time))
predictions, train_losses, test_losses = train_network(net, nn.MSELoss(), 
                  optimizer, trainloader, testloader, experiment_name,
                  num_epochs=200)
# Out:
# /usr/local/lib/python3.6/dist-packages/xarray/coding/times.py:426: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return array(a, dtype, copy=False, order=order)
# train Set: Epoch 01. loss: 0.613098
# test Set: Epoch 01. loss: 0.832866
# train Set: Epoch 02. loss: 0.604972
# test Set: Epoch 02. loss: 0.830326
# train Set: Epoch 03. loss: 0.598657
# test Set: Epoch 03. loss: 0.827025
# train Set: Epoch 04. loss: 0.591502
# test Set: Epoch 04. loss: 0.822070
# train Set: Epoch 05. loss: 0.583447
# test Set: Epoch 05. loss: 0.816465
# train Set: Epoch 06. loss: 0.574751
# test Set: Epoch 06. loss: 0.811984
# train Set: Epoch 07. loss: 0.565938
# test Set: Epoch 07. loss: 0.807977
# train Set: Epoch 08. loss: 0.557098
# test Set: Epoch 08. loss: 0.803623
# train Set: Epoch 09. loss: 0.548473
# test Set: Epoch 09. loss: 0.799904
# train Set: Epoch 10. loss: 0.540352
# test Set: Epoch 10. loss: 0.796407
# train Set: Epoch 11. loss: 0.532641
# test Set: Epoch 11. loss: 0.793095
# train Set: Epoch 12. loss: 0.525128
# test Set: Epoch 12. loss: 0.790183
# train Set: Epoch 13. loss: 0.517964
# test Set: Epoch 13. loss: 0.787496
# train Set: Epoch 14. loss: 0.511110
# test Set: Epoch 14. loss: 0.784987
# train Set: Epoch 15. loss: 0.504562
# test Set: Epoch 15. loss: 0.782827
# train Set: Epoch 16. loss: 0.498356
# test Set: Epoch 16. loss: 0.780856
# train Set: Epoch 17. loss: 0.492406
# test Set: Epoch 17. loss: 0.779087
# train Set: Epoch 18. loss: 0.486705
# test Set: Epoch 18. loss: 0.777501
# train Set: Epoch 19. loss: 0.481212
# test Set: Epoch 19. loss: 0.776091
# train Set: Epoch 20. loss: 0.475936
# test Set: Epoch 20. loss: 0.774875
# train Set: Epoch 21. loss: 0.470869
# test Set: Epoch 21. loss: 0.773813
# train Set: Epoch 22. loss: 0.465963
# test Set: Epoch 22. loss: 0.772905
# train Set: Epoch 23. loss: 0.461210
# test Set: Epoch 23. loss: 0.772073
# train Set: Epoch 24. loss: 0.456608
# test Set: Epoch 24. loss: 0.771426
# train Set: Epoch 25. loss: 0.452181
# test Set: Epoch 25. loss: 0.770940
# train Set: Epoch 26. loss: 0.447952
# test Set: Epoch 26. loss: 0.770641
# train Set: Epoch 27. loss: 0.443882
# test Set: Epoch 27. loss: 0.770501
# train Set: Epoch 28. loss: 0.439965
# test Set: Epoch 28. loss: 0.770446
# train Set: Epoch 29. loss: 0.436194
# test Set: Epoch 29. loss: 0.770522
# train Set: Epoch 30. loss: 0.432583
# test Set: Epoch 30. loss: 0.770707
# train Set: Epoch 31. loss: 0.429102
# test Set: Epoch 31. loss: 0.770995
# train Set: Epoch 32. loss: 0.425768
# test Set: Epoch 32. loss: 0.771354
# train Set: Epoch 33. loss: 0.422564
# test Set: Epoch 33. loss: 0.771789
# train Set: Epoch 34. loss: 0.419498
# test Set: Epoch 34. loss: 0.772288
# train Set: Epoch 35. loss: 0.416555
# test Set: Epoch 35. loss: 0.772852
# train Set: Epoch 36. loss: 0.413740
# test Set: Epoch 36. loss: 0.773451
# train Set: Epoch 37. loss: 0.411024
# test Set: Epoch 37. loss: 0.774084
# train Set: Epoch 38. loss: 0.408409
# test Set: Epoch 38. loss: 0.774783
# train Set: Epoch 39. loss: 0.405877
# test Set: Epoch 39. loss: 0.775506
# train Set: Epoch 40. loss: 0.403445
# test Set: Epoch 40. loss: 0.776300
# train Set: Epoch 41. loss: 0.401080
# test Set: Epoch 41. loss: 0.777076
# train Set: Epoch 42. loss: 0.398799
# test Set: Epoch 42. loss: 0.777897
# train Set: Epoch 43. loss: 0.396575
# test Set: Epoch 43. loss: 0.778729
# train Set: Epoch 44. loss: 0.394427
# test Set: Epoch 44. loss: 0.779611
# train Set: Epoch 45. loss: 0.392326
# test Set: Epoch 45. loss: 0.780471
# train Set: Epoch 46. loss: 0.390276
# test Set: Epoch 46. loss: 0.781355
# train Set: Epoch 47. loss: 0.388284
# test Set: Epoch 47. loss: 0.782278
# train Set: Epoch 48. loss: 0.386332
# test Set: Epoch 48. loss: 0.783198
# train Set: Epoch 49. loss: 0.384434
# test Set: Epoch 49. loss: 0.784108
# train Set: Epoch 50. loss: 0.382579
# test Set: Epoch 50. loss: 0.785028
# train Set: Epoch 51. loss: 0.380768
# test Set: Epoch 51. loss: 0.785962
# train Set: Epoch 52. loss: 0.378991
# test Set: Epoch 52. loss: 0.786952
# train Set: Epoch 53. loss: 0.377251
# test Set: Epoch 53. loss: 0.787879
# train Set: Epoch 54. loss: 0.375545
# test Set: Epoch 54. loss: 0.788837
# train Set: Epoch 55. loss: 0.373868
# test Set: Epoch 55. loss: 0.789748
# train Set: Epoch 56. loss: 0.372226
# test Set: Epoch 56. loss: 0.790679
# train Set: Epoch 57. loss: 0.370587
# test Set: Epoch 57. loss: 0.791669
# train Set: Epoch 58. loss: 0.368997
# test Set: Epoch 58. loss: 0.792599
# train Set: Epoch 59. loss: 0.367408
# test Set: Epoch 59. loss: 0.793548
# train Set: Epoch 60. loss: 0.365859
# test Set: Epoch 60. loss: 0.794546
# train Set: Epoch 61. loss: 0.364317
# test Set: Epoch 61. loss: 0.795562
# train Set: Epoch 62. loss: 0.362801
# test Set: Epoch 62. loss: 0.796625
# train Set: Epoch 63. loss: 0.361329
# test Set: Epoch 63. loss: 0.797629
# train Set: Epoch 64. loss: 0.359853
# test Set: Epoch 64. loss: 0.798636
# train Set: Epoch 65. loss: 0.358409
# test Set: Epoch 65. loss: 0.799639
# train Set: Epoch 66. loss: 0.356982
# test Set: Epoch 66. loss: 0.800666
# train Set: Epoch 67. loss: 0.355562
# test Set: Epoch 67. loss: 0.801629
# train Set: Epoch 68. loss: 0.354176
# test Set: Epoch 68. loss: 0.802610
# train Set: Epoch 69. loss: 0.352811
# test Set: Epoch 69. loss: 0.803610
# train Set: Epoch 70. loss: 0.351442
# test Set: Epoch 70. loss: 0.804591
# train Set: Epoch 71. loss: 0.350103
# test Set: Epoch 71. loss: 0.805571
# train Set: Epoch 72. loss: 0.348785
# test Set: Epoch 72. loss: 0.806572
# train Set: Epoch 73. loss: 0.347469
# test Set: Epoch 73. loss: 0.807568
# train Set: Epoch 74. loss: 0.346175
# test Set: Epoch 74. loss: 0.808602
# train Set: Epoch 75. loss: 0.344883
# test Set: Epoch 75. loss: 0.809573
# train Set: Epoch 76. loss: 0.343605
# test Set: Epoch 76. loss: 0.810539
# train Set: Epoch 77. loss: 0.342345
# test Set: Epoch 77. loss: 0.811500
# train Set: Epoch 78. loss: 0.341089
# test Set: Epoch 78. loss: 0.812490
# train Set: Epoch 79. loss: 0.339851
# test Set: Epoch 79. loss: 0.813472
# train Set: Epoch 80. loss: 0.338619
# test Set: Epoch 80. loss: 0.814459
# train Set: Epoch 81. loss: 0.337394
# test Set: Epoch 81. loss: 0.815423
# train Set: Epoch 82. loss: 0.336193
# test Set: Epoch 82. loss: 0.816376
# train Set: Epoch 83. loss: 0.334981
# test Set: Epoch 83. loss: 0.817329
# train Set: Epoch 84. loss: 0.333787
# test Set: Epoch 84. loss: 0.818314
# train Set: Epoch 85. loss: 0.332591
# test Set: Epoch 85. loss: 0.819267
# train Set: Epoch 86. loss: 0.331415
# test Set: Epoch 86. loss: 0.820264
# train Set: Epoch 87. loss: 0.330248
# test Set: Epoch 87. loss: 0.821174
# train Set: Epoch 88. loss: 0.329073
# test Set: Epoch 88. loss: 0.822160
# train Set: Epoch 89. loss: 0.327918
# test Set: Epoch 89. loss: 0.823105
# train Set: Epoch 90. loss: 0.326758
# test Set: Epoch 90. loss: 0.824073
# train Set: Epoch 91. loss: 0.325618
# test Set: Epoch 91. loss: 0.825040
# train Set: Epoch 92. loss: 0.324487
# test Set: Epoch 92. loss: 0.825984
# train Set: Epoch 93. loss: 0.323345
# test Set: Epoch 93. loss: 0.826941
# train Set: Epoch 94. loss: 0.322221
# test Set: Epoch 94. loss: 0.827896
# train Set: Epoch 95. loss: 0.321092
# test Set: Epoch 95. loss: 0.828822
# train Set: Epoch 96. loss: 0.319983
# test Set: Epoch 96. loss: 0.829754
# train Set: Epoch 97. loss: 0.318879
# test Set: Epoch 97. loss: 0.830744
# train Set: Epoch 98. loss: 0.317762
# test Set: Epoch 98. loss: 0.831720
# train Set: Epoch 99. loss: 0.316664
# test Set: Epoch 99. loss: 0.832708
# train Set: Epoch 100. loss: 0.315553
# test Set: Epoch 100. loss: 0.833602
# train Set: Epoch 101. loss: 0.314462
# test Set: Epoch 101. loss: 0.834591
# train Set: Epoch 102. loss: 0.313372
# test Set: Epoch 102. loss: 0.835502
# train Set: Epoch 103. loss: 0.312273
# test Set: Epoch 103. loss: 0.836419
# train Set: Epoch 104. loss: 0.311198
# test Set: Epoch 104. loss: 0.837457
# train Set: Epoch 105. loss: 0.310109
# test Set: Epoch 105. loss: 0.838391
# train Set: Epoch 106. loss: 0.309041
# test Set: Epoch 106. loss: 0.839338
# train Set: Epoch 107. loss: 0.307973
# test Set: Epoch 107. loss: 0.840281
# train Set: Epoch 108. loss: 0.306909
# test Set: Epoch 108. loss: 0.841255
# train Set: Epoch 109. loss: 0.305847
# test Set: Epoch 109. loss: 0.842220
# train Set: Epoch 110. loss: 0.304791
# test Set: Epoch 110. loss: 0.843149
# train Set: Epoch 111. loss: 0.303739
# test Set: Epoch 111. loss: 0.844058
# train Set: Epoch 112. loss: 0.302701
# test Set: Epoch 112. loss: 0.845017
# train Set: Epoch 113. loss: 0.301664
# test Set: Epoch 113. loss: 0.845980
# train Set: Epoch 114. loss: 0.300628
# test Set: Epoch 114. loss: 0.846922
# train Set: Epoch 115. loss: 0.299603
# test Set: Epoch 115. loss: 0.847953
# train Set: Epoch 116. loss: 0.298572
# test Set: Epoch 116. loss: 0.848898
# train Set: Epoch 117. loss: 0.297569
# test Set: Epoch 117. loss: 0.849883
# train Set: Epoch 118. loss: 0.296548
# test Set: Epoch 118. loss: 0.850891
# train Set: Epoch 119. loss: 0.295534
# test Set: Epoch 119. loss: 0.851815
# train Set: Epoch 120. loss: 0.294527
# test Set: Epoch 120. loss: 0.852829
# train Set: Epoch 121. loss: 0.293525
# test Set: Epoch 121. loss: 0.853734
# train Set: Epoch 122. loss: 0.292528
# test Set: Epoch 122. loss: 0.854734
# train Set: Epoch 123. loss: 0.291527
# test Set: Epoch 123. loss: 0.855640
# train Set: Epoch 124. loss: 0.290519
# test Set: Epoch 124. loss: 0.856625
# train Set: Epoch 125. loss: 0.289529
# test Set: Epoch 125. loss: 0.857563
# train Set: Epoch 126. loss: 0.288544
# test Set: Epoch 126. loss: 0.858475
# train Set: Epoch 127. loss: 0.287547
# test Set: Epoch 127. loss: 0.859476
# train Set: Epoch 128. loss: 0.286555
# test Set: Epoch 128. loss: 0.860384
# train Set: Epoch 129. loss: 0.285585
# test Set: Epoch 129. loss: 0.861353
# train Set: Epoch 130. loss: 0.284596
# test Set: Epoch 130. loss: 0.862254
# train Set: Epoch 131. loss: 0.283626
# test Set: Epoch 131. loss: 0.863160
# train Set: Epoch 132. loss: 0.282646
# test Set: Epoch 132. loss: 0.864146
# train Set: Epoch 133. loss: 0.281674
# test Set: Epoch 133. loss: 0.865034
# train Set: Epoch 134. loss: 0.280711
# test Set: Epoch 134. loss: 0.865988
# train Set: Epoch 135. loss: 0.279733
# test Set: Epoch 135. loss: 0.866917
# train Set: Epoch 136. loss: 0.278776
# test Set: Epoch 136. loss: 0.867899
# train Set: Epoch 137. loss: 0.277801
# test Set: Epoch 137. loss: 0.868821
# train Set: Epoch 138. loss: 0.276863
# test Set: Epoch 138. loss: 0.869766
# train Set: Epoch 139. loss: 0.275908
# test Set: Epoch 139. loss: 0.870691
# train Set: Epoch 140. loss: 0.274946
# test Set: Epoch 140. loss: 0.871590
# train Set: Epoch 141. loss: 0.273994
# test Set: Epoch 141. loss: 0.872539
# train Set: Epoch 142. loss: 0.273060
# test Set: Epoch 142. loss: 0.873429
# train Set: Epoch 143. loss: 0.272123
# test Set: Epoch 143. loss: 0.874392
# train Set: Epoch 144. loss: 0.271176
# test Set: Epoch 144. loss: 0.875314
# train Set: Epoch 145. loss: 0.270227
# test Set: Epoch 145. loss: 0.876262
# train Set: Epoch 146. loss: 0.269289
# test Set: Epoch 146. loss: 0.877134
# train Set: Epoch 147. loss: 0.268372
# test Set: Epoch 147. loss: 0.878136
# train Set: Epoch 148. loss: 0.267435
# test Set: Epoch 148. loss: 0.879067
# train Set: Epoch 149. loss: 0.266523
# test Set: Epoch 149. loss: 0.879976
# train Set: Epoch 150. loss: 0.265585
# test Set: Epoch 150. loss: 0.880932
# train Set: Epoch 151. loss: 0.264671
# test Set: Epoch 151. loss: 0.881884
# train Set: Epoch 152. loss: 0.263755
# test Set: Epoch 152. loss: 0.882784
# train Set: Epoch 153. loss: 0.262848
# test Set: Epoch 153. loss: 0.883763
# train Set: Epoch 154. loss: 0.261931
# test Set: Epoch 154. loss: 0.884697
# train Set: Epoch 155. loss: 0.261020
# test Set: Epoch 155. loss: 0.885627
# train Set: Epoch 156. loss: 0.260107
# test Set: Epoch 156. loss: 0.886500
# train Set: Epoch 157. loss: 0.259206
# test Set: Epoch 157. loss: 0.887515
# train Set: Epoch 158. loss: 0.258316
# test Set: Epoch 158. loss: 0.888357
# train Set: Epoch 159. loss: 0.257432
# test Set: Epoch 159. loss: 0.889312
# train Set: Epoch 160. loss: 0.256535
# test Set: Epoch 160. loss: 0.890243
# train Set: Epoch 161. loss: 0.255646
# test Set: Epoch 161. loss: 0.891217
# train Set: Epoch 162. loss: 0.254754
# test Set: Epoch 162. loss: 0.892112
# train Set: Epoch 163. loss: 0.253883
# test Set: Epoch 163. loss: 0.893018
# train Set: Epoch 164. loss: 0.253006
# test Set: Epoch 164. loss: 0.893941
# train Set: Epoch 165. loss: 0.252116
# test Set: Epoch 165. loss: 0.894805
# train Set: Epoch 166. loss: 0.251249
# test Set: Epoch 166. loss: 0.895725
# train Set: Epoch 167. loss: 0.250377
# test Set: Epoch 167. loss: 0.896687
# train Set: Epoch 168. loss: 0.249503
# test Set: Epoch 168. loss: 0.897637
# train Set: Epoch 169. loss: 0.248640
# test Set: Epoch 169. loss: 0.898607
# train Set: Epoch 170. loss: 0.247788
# test Set: Epoch 170. loss: 0.899571
# train Set: Epoch 171. loss: 0.246909
# test Set: Epoch 171. loss: 0.900432
# train Set: Epoch 172. loss: 0.246062
# test Set: Epoch 172. loss: 0.901357
# train Set: Epoch 173. loss: 0.245201
# test Set: Epoch 173. loss: 0.902266
# train Set: Epoch 174. loss: 0.244352
# test Set: Epoch 174. loss: 0.903185
# train Set: Epoch 175. loss: 0.243493
# test Set: Epoch 175. loss: 0.904094
# train Set: Epoch 176. loss: 0.242637
# test Set: Epoch 176. loss: 0.904964
# train Set: Epoch 177. loss: 0.241788
# test Set: Epoch 177. loss: 0.905947
# train Set: Epoch 178. loss: 0.240938
# test Set: Epoch 178. loss: 0.906887
# train Set: Epoch 179. loss: 0.240106
# test Set: Epoch 179. loss: 0.907769
# train Set: Epoch 180. loss: 0.239255
# test Set: Epoch 180. loss: 0.908673
# train Set: Epoch 181. loss: 0.238402
# test Set: Epoch 181. loss: 0.909511
# train Set: Epoch 182. loss: 0.237587
# test Set: Epoch 182. loss: 0.910369
# train Set: Epoch 183. loss: 0.236740
# test Set: Epoch 183. loss: 0.911173
# train Set: Epoch 184. loss: 0.235918
# test Set: Epoch 184. loss: 0.912061
# train Set: Epoch 185. loss: 0.235076
# test Set: Epoch 185. loss: 0.912905
# train Set: Epoch 186. loss: 0.234241
# test Set: Epoch 186. loss: 0.913771
# train Set: Epoch 187. loss: 0.233419
# test Set: Epoch 187. loss: 0.914672
# train Set: Epoch 188. loss: 0.232575
# test Set: Epoch 188. loss: 0.915409
# train Set: Epoch 189. loss: 0.231772
# test Set: Epoch 189. loss: 0.916336
# train Set: Epoch 190. loss: 0.230946
# test Set: Epoch 190. loss: 0.917155
# train Set: Epoch 191. loss: 0.230127
# test Set: Epoch 191. loss: 0.917961
# train Set: Epoch 192. loss: 0.229323
# test Set: Epoch 192. loss: 0.918768
# train Set: Epoch 193. loss: 0.228510
# test Set: Epoch 193. loss: 0.919591
# train Set: Epoch 194. loss: 0.227697
# test Set: Epoch 194. loss: 0.920319
# train Set: Epoch 195. loss: 0.226898
# test Set: Epoch 195. loss: 0.921272
# train Set: Epoch 196. loss: 0.226082
# test Set: Epoch 196. loss: 0.922124
# train Set: Epoch 197. loss: 0.225286
# test Set: Epoch 197. loss: 0.922994
# train Set: Epoch 198. loss: 0.224470
# test Set: Epoch 198. loss: 0.923786
# train Set: Epoch 199. loss: 0.223671
# test Set: Epoch 199. loss: 0.924788
# train Set: Epoch 200. loss: 0.222872
# test Set: Epoch 200. loss: 0.925522

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Performance of {} Neural Network During Training'.format(experiment_name))
plt.legend(loc='best')
plt.show()

corr, _ = pearsonr(test_predictands, predictions)
rmse = mean_squared_error(test_predictands, predictions) ** 0.5
plot_nino_time_series(test_predictands, predictions, '{} Predictions. Corr: {:3f}. RMSE: {:3f}.'.format(experiment_name,
                                                                      corr, rmse))

# %%
from google.colab import files
files.download('twolayerCNN_MPI_1860-01-01_2200-12-31_lead_time{}.pt'.format(lead_time))
